# %% [markdown]
# # jQuery
# - jQuery的引入：
#     - 老版本：
#             $(function(){
#                 书写jQuery代码
#             })
#     - 新版本：
#            直接在script中书写代码，但是这个script要在元素后面书写
# ## 选择器
# - 代码：$("选择器").css("width", "500px").css("height","500px")
#     - 以下选择器都是指在该代码中选择器的位置
# - 中文文档参看：https://jquery.cuishifeng.cn/index.html
# - js对象和jQuery的转换
#     - js对象转成jQuery对象；$(js对象)
#     - juqery对象转换成js对象：$(...).get()方法，将获取的元素返回成js对象数组
#
#
# ## 选择器
# #### 基本选择器：
# - 基本
#     - tag
#     - 可以选择多个标签，tags1, tags2
# - 层级：
#     - parent 空格 childs
#     - parent > child：第一个符合要求的子元素
#     - prev + tag/* 兄弟选择器：只能选中下一个符合要求的兄弟元素[找位置，判断类型]
#     - prev ~ siblings 选择下面多个符合要求的同级元素
#
#
# #### 基本筛选器
# - :first  选择标签下的第一个元素
# - :last
# - :not(selector) 选择标签下不含某个特点的元素
# - :eq(index) 选择等于某个index的元素
# - :gt(index) 选择大于。。。
# - :lt(index) 选择小于。。。
# - :header  选择所有的head
# - :animated选择正在进行动画效果的元素
# - :focus  选择当前焦点（即光标）所在的元素。
# - :target 选择锚点所在的元素
#
# #### 内容选择器
# - :contains(text) 选择含有某个文本的元素
# - :empty 选择文本为空的元素
# - :has(selector) 选择是否具有指定子元素的元素
# - :parent  选择有儿子元素的元素，没有的就不选中
#
# #### 属性选择器
# - 和xpath的用法很像
# - [attribute]
# - [attribute=value]
# - [attribute!=value]:选择属性不等于
# - [attribute^=value]：选择属性以什么开头的
# - [attribute$=value]：选择属性以什么结尾的
# - [attribute*=value]：选择属性包含指定字符的
# - [attrSel1][attrSel2][attrSelN]：多属性选择器$
#
# #### 表单选择器
# - :input
# - :text
# - :password
# - :radio
# - :checkbox
# - :submit
# - :image
# - :reset
# - :button
# - :file
# - :enabled
# - :disabled
# - :checked
# - :selected
#
# #### 子元素选择器
# - :first-child：为每个父级元素匹配第一个指定的子元素，若一个元素不是指定的元素类型，则选不中
#     - 比如["div:first-child"]:意思是先找到所有div标签，然后找他们的的父元素，再选中这个父元素下的第一个类型为div的标签，若类型不是div，就不会返回它它
# - :first-of-type：
#     - 意思是先找到所有div标签，然后找他们的的父元素，然后返回该父元素的所有div标签组成的列表，然后返回这个列表中第一个元素
# - :last-child：原理和first-child一样
# - :last-of-type
# - :nth-child：原理和first-child一样，只是找的是第index位置的元素
# - :nth-last-child(index)：倒数
# - :nth-last-of-type()
# - :nth-of-type()
# - :only-child：道理和first-child一样，只是说该父元素有且只有一个子元素
# - :only-of-type

# %% [raw]
# # jquery的简单使用
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>jquery的使用</title>
# <script src="./jquery-3.4.1.min.js"></script>
# <script>
# 	<!-- 早期版本写法 -->
# 	// $(function(){
# 	// 	// 此处书写jQuery代码
# 	// 	$("body").css("background", "yellow");
# 	// })
# </script>
# </head>
# <body>
#
# </body>
# </html>
# <script>
# 	<!-- 新版本写法，可以省略function,但必须放在元素后面 -->
# 	$("body").css("background", "cyan");
# 	console.log($())
# </script>

# %% [raw]
# # 基本的选择
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>jquery的使用</title>
# <script src="./jquery-3.4.1.min.js"></script>
# </head>
# <body>
#     <div>
#     	<div>说一段神话</div>
#     	<div class="family">话说那么一家</div>
#     	<div>这家夫妻俩</div>
#     	<div id="wawa">生了个怪娃娃</div>
#     </div>
# </body>
# </html>
# <script>
# 	$("div").css("border", "3px solid black").css("background", "cyan").css("font-size","20px").css("margin", "20px");
# 	$(".family+*").css("font-weight", "bold");
# 	$(".family~*").css("color", "red");
# </script>

# %% [markdown]
# ## 筛选
# - 在选择器中进一步筛选出想要的元素
# #### 过滤
# - eq(index|-index)
# - first()
# - last()
# - hasClass(class)
# - filter(expr|obj|ele|fn)：详情参见jQuery手册中文
# - is(expr|obj|ele|fn)
# - map(callback)
# - has(expr|ele)
# - not(expr|ele|fn)
# - slice(start,[end])
# #### 查找
# - children([expression]):
#     - 取得一个包含匹配的元素集合中每一个元素的所有子元素的元素集合。
#     - 可以通过可选的表达式来过滤所匹配的子元素。注意：parents()将查找所有祖辈元素，而children()只考虑子元素而不考虑所有后代元素。
# - closet(expr|object|element):
#     - closest会首先检查当前元素是否匹配，如果匹配则直接返回元素本身。如果不匹配则向上查找父元素，一层一层往上，直到找到匹配选择器的元素。如果什么都没找到则返回一个空的jQuery对象。
#     - closest和parents的主要区别是：1，前者从当前元素开始匹配寻找，后者从父元素开始匹配寻找；2，前者逐级向上查找，直到发现匹配的元素后就停止了，后者一直向上查找直到根元素，然后把这些元素放进一个临时集合中，再用给定的选择器表达式去过滤；3，前者返回0或1个元素，后者可能包含0个，1个，或者多个元素。
# - find(epr/obj/element):搜索所有与指定表达式匹配的元素。
# - next([expr])：只找一个
# - nextAll([expr]):选中找到元素之后的所有同级别元素
# - nextUntil([e|e][,final]):final定义的是找到哪个元素停止查找
# - prev([expr])
# - prevAll([expr])
# - prevUntil([e|e][,f])
# - parent([expr])：只找一个父级元素
# - parents([expr]):向外逐渐查找所有父级元素，并返回这些父级元素组成的列表，当然可以进一步筛选
# - parentsUntil([e|e][,final])：向外找到哪一个父级元素就停止查找
# - siblings([expr]):查找所有的兄弟元素
# - offsetParent():返回父元素中第一个其position设为relative或者absolute的元素。此方法仅对可见元素有效。
#
#
# #### 串联
# - add():
#     - 第一种用法：添加一个元素到一组匹配的元素中
#         - $("div").add("span"),找到div和span两个元素】
#     - 第二种用法：动态生成一个元素并添加至匹配的元素中
#         - 就是给他添加子元素
#     - 第三种用法：为匹配的元素添加属性
#         - $("div").add(document.getElementById("idd")
# - addBack():比如nextAll是不包含自己本身的，所以可以用addBack()使之包含本身
# - end():回到最近的一个"破坏性"操作之前。即，将匹配的元素列表变为前一次的状态。
# - contents():查找匹配元素内部所有的子节点（包括文本节点）。如果元素是一个iframe，则查找文档内容
# - 注：$(元素节点):可以将js节点变成jQuery对象

# %% [raw]
# # map的使用
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>jquery的使用</title>
# <script src="./jquery-3.4.1.min.js"></script>
# </head>
# <body>
#     <ul>
#     	<li>我有一只小毛驴</li>
#     	<li>我从来都不骑</li>
#     	<li>啦啦啦啦啦</li>
#     </ul>
# </body>
# </html>
# <script>
# 	var colors = ['red', 'yellow', 'blue'];
# 	var index = 0;
# 	$("li").map(function(){
# 		// 为每个li设置不同的颜色背景
# 		$(this).css("background", colors[index]);
# 		index++;
# 	})
# </script>

# %% [markdown]
# # css
# #### CSS
# - css(name|pro|[,val|fn])：多个css用大括号包括
#     - $("div").css({'width':"100px", "height":"100px"})
# - jQuery.cssHooks:兼容性处理
#
# #### 位置
# - offset([coordinates])
#     - 参数：coordinates{top,left}必需。规定以像素计的 top 和 left 坐标。
#     - 获取匹配元素在当前视口（当前页面）的相对偏移。
# - position()
#     - 获取匹配元素相对父元素的偏移。
#     - 返回的对象包含两个整型属性：top 和 left。为精确计算结果，请在补白、边框和填充属性上使用像素单位。此方法只对可见元素有效。
# - scrollTop([val])：
#     - 获取匹配元素相对滚动条顶部的偏移。
#     - 此方法对可见和隐藏元素均有效。
# - scrollLeft([val])
#
# #### 尺寸
# - height([val|fn]):设置高度，也可以将其赋值给一个变量，得到其宽度
# - width([val|fn])：
# - innerHeight()
# - innerWidth()：包括补白，但不包括边框
# - outerHeight([options])：获取第一个匹配元素外部高度（默认包括补白和边框）。
# - outerWidth([options])

# %% [markdown]
# # 属性选择器
# #### 属性
# - attr：自己添加的属性，比如a标签加sex，age等
#     - 它也可以获取固有属性和设置固有属性
#     - 这个属性如果原来有，就会覆盖它
#     - removeAttr("attr")
#     - attr同比prop用的更多
# - prop：标签固有属性，比如a标签href，target，name等
#     - 可以获取或设置属性的值
#     - removeAttr("prop")
# #### css类
# - addClass(class|fn)：为每个匹配的元素添加指定的类名，如果该class原来有值，并不会覆盖原来的值，只是添加（因为class可以允许有多个值）
# - removeClass([class|fn])：只是移除某一个属性
# - toggleClass(class|fn[,sw])：如果存在指定的class（不存在）就删除（添加）一个类，起到切换class值
#
# #### HTML代码/文本/值
# - html([val|fn])：相当于innerHTML
# - text([val|fn]):相当于innerTEXT
# - val([val|fn|arr]):相当于表单元素的value值，和表单这一类的标签相适用，设置表单的value值

# %% [raw]
# #attr和prop的简单使用
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>jquery的使用</title>
# <script src="./jquery-3.4.1.min.js"></script>
# <style>
# 	div{
# 		width: 500px;
# 		margin: 20px;
# 	}
# </style>
# </head>
# <body>
#     <input id="input" type="text" name="username" value="" />
# </body>
# </html>
# <script>
# 	var username = $("input").prop("name");
# 	console.log(username);
# 	var username1 = $("input").attr("name");
# 	console.log(username1);
# 	$("input").prop("type", "password");
# 	$("input").attr("placeholder", "请填写");
# 	$("input").removeAttr("name");
# 	// $("input").removeProp("name");
# 	// 3.4.1这个版本有问题。removeProp删除不了
# 	var input = document.getElementById("input")
# 	console.log(window.input);
#
#     // $("#one").mouseout(function(){
# 	// 	$("#one").removeAttr("class");
# 	// 	// 该方法会删除所有的class属性
# 	// });
#
# 	$("#one").mouseout(function(){
# 		$("#one").removeClass("bg");
# 	});
# 	// 只删除bg属性
#
# </script>

# %% [raw]
# # addClass举例
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>jquery的使用</title>
# <script src="./jquery-3.4.1.min.js"></script>
# <style>
# 	div{
# 		width: 500px;
# 		margin: 20px;
# 		border: 3px solid red;
# 	}
# 	.bg{
# 		background: yellow;
# 	}
# 	.big{
# 		font-size: 50px;
# 	}
#
# </style>
# </head>
# <body>
#     <div id="one" class="big">我是一个好人</div>
# </body>
# </html>
# <script>
# 	// $("#one").mouseover(function(){
# 	// 	$("#one").attr("class", "bg");
# 	// });
# 	// 这样的添加方式会覆盖原来的big属性
#
# 	$("#one").mouseover(function(){
# 		$("#one").addClass("bg");
# 	});
# </script>

# %% [markdown]
# ## 文档处理
# #### 内部插入
# - append(content|fn)：在指定的元素最后添加内容(appendChild的封装)
#     - $("#one").append("u我是序列 /u")
# - appendTo(content)：将内容添加到指定标签的最后
#     - $("u我是序列/u").appendTo("#one")
# - prepend(content|fn)：在指定标签的开头添加内容
# - prependTo(content)：将内容添加到指定标签的开头
# #### 外部插入
# - after(content|fn)：在每个匹配的元素之后插入内容。
# - before(content|fn)：
# - insertAfter(content)：把所有匹配的元素插入到另一个、指定的元素元素集合的后面。
# - insertBefore(content)
# #### 包裹
# - wrap(html|ele|fn):把所有匹配的元素用其他元素的结构化标记包裹起来。一个一个的单独包裹
# - unwrap():解除选中元素外面的第一个元素
# - wrapAll(html|ele)：把相同元素的标签都包装到一个标签中，哪怕相同的标签中间还有其他标签，相当于把相同的标签集合到一起
# - wrapInner(html|ele|fn)：将每一个匹配的元素的子内容(包括文本节点)用一个HTML结构包裹起来
# #### 替换
# - replaceWith(content|fn):将所有匹配的元素替换成指定的HTML或DOM元素。
# - replaceAll(selector):用指定的元素替换掉所有匹配到的元素。
# #### 删除
# - empty()删除匹配的元素集合中所有的子节点
# - remove([expr])从DOM中删除所有匹配的元素。
# - detach([expr])
#     - 从DOM中删除所有匹配的元素。
#     - 这个方法不会把匹配的元素从jQuery对象中删除，因而可以在将来再使用这些匹配的元素。与remove()不同的是，所有绑定的事件、附加的数据等都会保留下来。
#
# #### 复制
# - clone([Even[,deepEven]])
#     - 参数
#     - 1:一个布尔值（true 或者 false）指示事件处理函数是否会被复制。
#     - 2:一个布尔值，指示是否对事件处理程序和克隆的元素的所有子元素的数据应该被复制。

# %% [raw]
# # wrap的使用
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>jquery的使用</title>
# <script src="./jquery-3.4.1.min.js"></script>
# <style>
# 	div{
# 		width: 500px;
# 		margin: 20px;
# 		border: 3px solid red;
# 	}
#
# </style>
# </head>
# <body>
#     <div id="one" class="big">我是一个好人</div>
#     <p>我感觉自己快要坚持不住了</p>
#     <p>Oh， MyGod</p>
#     <div>每天笑嘻嘻</div>
# </body>
# </html>
# <script>
# 	// $("div").wrap("<span></span>");
# 	$("div").wrapInner("<span/>");
# 	// $("div").wrapInner("<span/>");
# 	// $("div").wrapAll("<span/>")
# </script>

# %% [markdown]
# ## 事件
# #### 页面加载
# - 页面加载完成之后运行
# - 简化写法$(function(){});
# - 完整写法$(document).ready(function(){在这里写你的代码...});
#
# #### 事件处理
# - on(eve,[sel],[data],fn)：添加指定事件，相当于addEventListener
# - off(eve,[sel],[fn])：关闭指定事件 相当于removerEventListener
# - one(type,[data],fn)：
#     - 为每一个匹配元素的特定事件（像click）绑定一个一次性的事件处理函数。
#     - 在每个对象上，这个事件处理函数只会被执行一次。这个事件处理函数会接收到一个事件对象，可以通过它来阻止（浏览器）默认的行为。如果既想取消默认的行为，又想阻止事件起泡，这个事件处理函数必须返回false。
# - trigger(type,[data])：
#     - 在每一个匹配的元素上触发某类事件。
#     - 这个函数也会导致浏览器同名的默认行为的执行。比如，如果用trigger()触发一个'submit'，则同样会导致浏览器提交表单。如果要阻止这种默认行为，应返回false。
# - triggerHandler(type, [data])：与trigger类似
#     -  第一，他不会触发浏览器默认事件。
#     - 第二，只触发jQuery对象集合中第一个元素的事件处理函数。
#     - 第三，这个方法的返回的是事件处理函数的返回值，而不是据有可链性的jQuery对象。此外，如果最开始的jQuery对象集合为空，则这个方法返回 undefined 。
#
# #### 事件切换
# - toggle([speed],[easing],[fn])
#     - 用于绑定两个或多个事件处理器函数，以响应被选元素的轮流的 click 事件。
#     - 如果元素是可见的，切换为隐藏的；如果元素是隐藏的，切换为可见的。
# - hover([over,]out)：
#     - 当鼠标移动到一个匹配的元素上面时，会触发指定的第一个函数。当鼠标移出这个元素时，会触发指定的第二个函数。而且，会伴随着对鼠标是否仍然处在特定元素中的检测（例如，处在div中的图像），如果是，则会继续保持“悬停”状态，而不触发移出事件（修正了使用mouseout事件的一个常见错误）。
#
# #### 事件
# - 事件,和DOM0中的一样
#         blur([[data],fn])
#         change([[data],fn])
#         click([[data],fn])
#         dblclick([[data],fn])
#         error([[data],fn])1.8-
#         focus([[data],fn])
#         focusin([data],fn)
#         focusout([data],fn)
#         keydown([[data],fn])
#         keypress([[data],fn])
#         keyup([[data],fn])
#         mousedown([[data],fn])
#         mouseenter([[data],fn])
#         mouseleave([[data],fn])
#         mousemove([[data],fn])
#         mouseout([[data],fn])
#         mouseover([[data],fn])
#         mouseup([[data],fn])
#         resize([[data],fn])
#         scroll([[data],fn])
#         select([[data],fn])
#         submit([[data],fn])

# %% [raw]
# #toggle的应用
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>jquery的使用</title>
# <script src="./jquery-3.4.1.min.js"></script>
# <style>
#
# </style>
# </head>
# <body>
#     <div>
#     	<img src="./美女图片.jpg" alt="">
#     </div>
#     <button>隐藏</button>
#     <button>显示</button>
#     <button>切换</button>
# </body>
# </html>
# <script>
# 	$("button:first").click(function(){
# 		$("img").hide(1000);
# 	});
#
# 	$("button:contains(显示)").click(function(){
# 		$("img").show(1000);
# 	});
#
# 	$("button:eq(2)").click(function(){
# 		$("img").toggle(1000);
# 	});
# 	// 切换元素的显示状态
# </script>

# %% [markdown]
# # ajax选择器
# #### ajax 请求
# - $.ajax(url,[settings])
#     - 通用ajax功能
#     - 参数：{type: , data: , url: , sucess: function(){}, error: function(){}}
#         - type:ajax操作方式：只有get和post
#         - data：传递给服务器的数据
#         - url：给服务器哪个js文件
#         - dataType:设置服务器返回数据的格式
# - $.get(url,[data],[fn],[type])
#     - 参数：url,[data],[callback],[type]
#         - url:待载入页面的URL地址
#         - data:待发送 Key/value 参数。
#         - callback:载入成功时回调函数。
#         - type:返回内容格式，xml, html, script, json, text, _default。
# - $.getJSON(url,[data],[fn])
#     - 参数：url,[data],[callback]
#         - url:发送请求地址。
#         - data:待发送 Key/value 参数。
#         - callback:载入成功时回调函数。
# - $.getScript(url,[callback])
#     - 参数：url,[callback]
#         - url:待载入 JS 文件地址。
#         - callback:成功载入后回调函数。
# - $.post(url,[data],[fn],[type])
#     - 和get操作一摸一样
#     - 参数：url,[data],[callback],[type]
#         - url:待载入页面的URL地址
#         - data:待发送 Key/value 参数。
#         - callback:载入成功时回调函数。
#         - type:返回内容格式，xml, html, script, json, text, _default。
# #### ajax 事件
# - ajaxComplete(callback)
# - ajaxError(callback)
# - ajaxSend(callback)
# - ajaxStart(callback)
# - ajaxStop(callback)
# - ajaxSuccess(callback)
# #### 其它
# - load(url,[data],[callback])
#     - 参数：url,[data,[callback]]
#         - url:待装入 HTML 网页网址。
#         - data:发送至服务器的 key/value 数据。在jQuery 1.3中也可以接受一个字符串了。
#         - callback:载入成功时回调函数。
# - $.ajaxPrefilter([type],fn)
# - $.ajaxSetup([options])
# - serialize()：序列表表格内容为字符串。
# - serializeArray()：
#     - 序列化表格元素 (类似 '.serialize()' 方法) 返回 JSON 数据结构数据。
#     - 此方法返回的是JSON对象而非JSON字符串。需要使用插件或者第三方库进行字符串化操作。
#     - 返回的JSON对象是由一个对象数组组成的，其中每个对象包含一个或两个名值对——name参数和value参数（如果value不为空的话）

# %% [raw]
# # ajax举例
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <title>jquery中的ajax的使用</title>
# <script src="jquery-3.4.1.min.js"></script>
# </head>
# <body>
#    <button>ajax</button>
#    <button>get</button>
#    <button>post</button>
#    <button>getJSON</button>
#    <button>getScript</button>
#    <button>load</button>
#    <hr />
#    <div id="text"></div>
# </body>
# </html>
#
# <script>
# 	/* $.ajax的使用
# 	$("button:first").click(function(){
# 		// ajax请求数据
# 		$.ajax({
# 			type:"POST",
# 			data:{"name":"关二哥"},
# 			url:"b.php",
# 			dataType:"text",
# 			success:function(data){
# 				$("#text").html(data);
# 			},
# 			error:function(){
# 				alert("不好意思，出错了");
# 			}
# 		});
# 	})
# 	*/
#
# 	/*$.get的使用*/
# 	/*
# 	$("button:eq(1)").click(function(){
# 		$.get("b.php", "name=taotao&age=23", function(data){
# 			// 若想得到b文件返回给我们输入的name值本身，则b.php文件中这样写: echo $_GET['name'];
# 			$("#text").html(data);
# 		});
# 	})
# 	*/
# 	// $.post和get方法一模一样
#
# 	// load()的使用
# 	$("button:last").click(function(){
# 		// 加载页面内容（简单写法
# 		$("#text").load("./javascript.html");
# 	})
#
#
# </script>

# %% [markdown]
# # 效果
# - show([speed,[e],[fn]])显示隐藏的匹配元素。speed可以设为"slow"/"fast"或者毫秒数，表示显示的快慢
# - hide([speed,[e],[fn]])隐藏显示的元素
# - toggle([s],[e],[fn])：切换状态
#     - 用于绑定两个或多个事件处理器函数，以响应被选元素的轮流的 click 事件。
#     - 如果元素是可见的，切换为隐藏的；如果元素是隐藏的，切换为可见的。
#
#
# #### 滑动
# - slideDown([s],[e],[fn])
#     - 通过高度变化（向下增大）来动态地显示所有匹配的元素，在显示完成后可选地触发一个回调函数。
#     - 这个动画效果只调整元素的高度，可以使匹配的元素以“滑动”的方式显示出来。
# - slideUp([s,[e],[fn]])
# - slideToggle([s],[e],[fn])：来回切换上拉与下拉，上面两个的组合
#
# #### 淡入淡出
# - fadeIn([s],[e],[fn])
#     - 通过不透明度的变化来实现所有匹配元素的淡入效果，并在动画完成后可选地触发一个回调函数。
#     - 这个动画只调整元素的不透明度，也就是说所有匹配的元素的高度和宽度不会发生变化。
# - fadeOut([s],[e],[fn])
#     - 淡出效果
# - fadeTo([[s],o,[e],[fn]])
#     - 把所有匹配元素的不透明度以渐进方式调整到指定的不透明度，并在动画完成后可选地触发一个回调函数。
# - fadeToggle([s,[e],[fn]])
#     - 来回切换淡入淡出效果
# #### 自定义
# - animate(p,[s],[e],[fn])
#     - 用于创建自定义动画的函数。
#     - 这个函数的关键在于指定动画形式及结果样式属性对象。这个对象中每个属性都表示一个可以变化的样式属性（如“height”、“top”或“opacity”）。注意：所有指定的属性必须用小驼峰命名
#     - 而每个属性的值表示这个样式属性到多少时动画结束。如果是一个数值，样式属性就会从当前的值渐变到指定的值。如果使用的是“hide”、“show”或“toggle”这样的字符串值，则会为该属性调用默认的动画形式。
# - stop([c],[j])
#     - 停止所有在指定元素上正在运行的动画。
# - delay(d,[q])
#     - 设置一个延时来推迟执行队列中之后的项目。
# - finish([queue])
#     - 停止当前正在运行的动画，删除所有排队的动画，并完成匹配元素所有的动画。
# #### 设置
# - jQuery.fx.off
#     - 全局动画设置，关闭动画效果

# %% [markdown]
# # 事件对象
#         eve.currentTarget
#         eve.data
#         eve.delegateTarget1.7+
#         eve.isDefaultPrevented()
#         eve.isImmediatePropag...()
#         eve.isPropagationStopped()
#         eve.namespace
#         eve.pageX
#         eve.pageY
#         eve.preventDefault()
#         eve.relatedTarget
#         eve.result
#         eve.stopImmediatePro...()
#         eve.stopPropagation()
#         eve.target
#         eve.timeStamp
#         eve.type
#         eve.which

# %% [markdown]
# # 工具
# - $.each(object, [callback])：
#     - 遍历数组和对象
#     - object:需要遍历的对象或数组。
#     - callback:每个成员/元素执行的回调函数。
# - $.extend([d],tgt,obj1,[objN])
#     - 合并对象，若有相同的键值，则后面的覆盖前面的
# - $.grep(array,fn,[invert])
#     - 使用过滤函数过滤数组元素。
#     - 此函数至少传递两个参数：待过滤数组和过滤函数。过滤函数必须返回 true 以保留元素或 false 以删除元素。

# %% [raw]
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <title>动画</title>
# <script src="./jquery-3.4.1.min.js"></script>
# <style>
# 	#ball{
# 		width: 100px;
# 		height: 100px;
# 		background: yellow;
# 		position: absolute;
# 		left: 0;
# 		top: 100;
# 	}
# </style>
# </head>
# <body>
#     <button>animate</button>
#     <button>stop</button>
#     <hr />
#     <div id="ball"></div>
# </body>
# </html>
#
# <script>
# 	// each的用法
# 	var jihe = ["apple", "plum", "grapge", "bananla"];
# 	$.each(jihe, function(i, v){
# 		console.log(v);
# 	});
# 	// function需要传入两个参数
#
# 	var native_fruits = {"apple": 23, "orange":24, "mango":45};
# 	$.each(native_fruits, function(n, v){
# 		console.log(n, v, typeof v);
# 	});
# 	var jihe = ["apple", "plum", "grapge", "bananla"];
#
#
# 	// extend的用法
# 	var foreign_fruits = {"dragon":55, "peach":80};
# 	var fruits = $.extend(native_fruits, foreign_fruits);
# 	console.log(fruits);
#
# 	// grep的用法
# 	var result = $.grep( [0,1,2], function(n,i){
# 		 return n > 0;
# 		});
# 	console.log(result);
# </script>

# %% [markdown]
# # 核心
# - 队列控制
# - queue(e,[q])
#     - 显示或操作在匹配元素上执行的函数队列
#     - element:检查附加列队的DOM元素
#     - queueName:字符串值，包含序列的名称。默认是 fx, 标准的效果序列。
# - dequeue([queueName])
#     - 从队列最前端移除一个队列函数，并执行他。
# - clearQueue([queueName])
#     - 清空对象上尚未执行的所有队列
#     - 如果不带参数，则默认清空的是动画队列。这跟 stop(true)类似，但stop(true)只能清空动画队列，而这个可以清空所有通过 .queue() 创建的队列。

# %% [raw]
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <script src="./jquery-3.4.1.min.js"></script>
# <title>核心操作</title>
# </head>
# <body>
#     <button>队列操作</button>
# </body>
# </html>
# <script>
# 	$("button:first").click(function(){
# 		// myqueue就是一个队列
# 		$(document).queue("myqueue", function(next){
# 			alert("1111");
# 			next();
# 		}).queue("myqueue", function(next){
# 			console.log("脱衣服");
# 			next();
# 		}).queue("myqueue", function(next){
# 			console.log("盖被子");
# 			next();
# 		}).queue("myqueue", function(next){
# 			console.log("闭眼睛");
# 			next();
# 		}).queue("myqueue", function(next){
# 			console.log("不好意思，忘记关灯了");
# 		}).queue("myqueue", function(next){
# 			console.log("不管了，睡觉了");
# 		})
# 	});
# 	// 队列值的获取
# 	// 先查看添加的队列
# 	console.log($(document).queue("myqueue"));
# 	$(document).dequeue("myqueue");
#
# </script>
