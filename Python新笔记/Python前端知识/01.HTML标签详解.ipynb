# %% [markdown]
# # html
# - 有语义与无语义的解释
#     - 有语义是指该标签一写出来就知道它表示啥，比如h标签就是标题，p就是段落
#     - 无语义就是没具体含义，如div，span

# %% [markdown]
# # body标签
# - 属性
#     - bgcolor：设置背景颜色
#     - background:设置页面的背景图片
#         - 注意：如果同时设置背景颜色和背景图片，优先显示背景图片
#     - link:设置全部链接的颜色
#     - alink：设置鼠标点击时超链接的颜色
#     - vlink：设置鼠标点击过后的颜色
#
# ## 标题标签：h
# - 通过h1-h6标签来定义的，一个网页中h1只能有一个,他有搜索引擎优化的作用
#
# ## 样式标签
# - 1.单纯的样式标签：
#     - b标签：加粗
#     - i标签：倾斜
#     - u标签：下划线
# - 2.有强调意义的样式标签
#     - strong：具有强调意义的粗体，除了加粗效果以外，还实现SEO搜索引擎优化
#     - cite：具有强调意义的斜体字效果
#     - em：具有强调意义的斜体字效果，em>cite强调效果
# - 3.自定义的样式标签
#     - font标签：自定义字体标签
#         - color属性，size属性，face属性（设置字体类型）
#
# ## 格式标签
# - p标签：段落标签
# - br标签：强制换行标签
# - hr：水平线标签
#     - width属性：设置水平线的宽度
#     - color属性：设置水平线的颜色
# - center标签：水平居中标签
# - sub定义下标字   sup定义上标字   ins定义插入字   del定义删除字
# - div标签：无意义标签，作用：在页面布局中进行页面划块和分割页面。独占一行
# - span标签：无意义标签：在页面布局中用于存放文本内容。不独占一行，中间会空一格
#
# ## 块标签和行内标签的特征
# - 块标签，又称块元素，块级标签，块级元素：
# - 行内标签，又称行标签，行级元素，行内元素，内联元素
# - 两者区别：
#     - 块元素可以设置宽度和高度，行内元素不可以
#     - 块状元素不可以和其他元素一行共存，内联元素可以和内联元素仪器共存
#     - 块状元素可以包含内联元素，内联元素不可以包含块状元素
#     - div标签时块元素的代表，span是行内元素的代表
#
# ## 列表标签
# - ul标签：无序列表，type属性可以修改前面圆点的样式
#     - "desc":表示圆点
#     - "square":表示正方形
#     - "circle"：表示空心圆，即环
#     - 小技巧：快捷书写多个li的方法，只有安装了emmet才有效
#         - li{$}*10. $
# - ol标签：有序列表
#     - type属性：设置表示类型，比如1，罗马数字，a，A等
#     - start属性：设置标识开始值
# - dl标签：自定义列表
#     - dt和dd是放于dl标签内，标签dt与dd处于dl下相同级。也就是dt不能放入dd内，dd不能放入dt内。
#     - 在dl下，dt与dd处于同级标签。DD标签可以若干。同时不能不加dl地单独使用dt标签或dd标签。
#
# ## 超链接标签
# - a标签：属性
#     - href属性：用于设置超链接跳转或者打开的文件地址
#         - #：当href="#"时或者什么都不写的时候表示回到网页顶部，HTML中#代表本网页
#         - ####：表示什么都不做，不要跳转
#         - javascript:void(0); :这种写法和####一样，是企业级标准写法。在body中的顶部一般会写，为了让css修饰网页成功
#     - target属性：设置超链接的打开方式
#         - _self:当前自己页面打开（默认值）
#         - _blank:在新的页面打开（在框架集中使用）
#         - _top:在页面顶部打开（在框架集中使用）
#         - _parent:在父级页面打开（在框架集中使用）
#
# - 超链接的三种使用方式：
#     - 1.普通超链接
#         - 即网址
#     - 2.锚点连接
#         - 第一步：在需要跳转到的目的地，使用a标签和name属性（或者id属性）定义锚点位置和名称
#         - 第二步：在需要点击跳转的位置，使用正常的超链接设置跳转位置，必须以#开头
#         - 注意：锚点的设置可以使用包含id名称的其他标签来代替a标签和name属性设定
#                 <a href="javascript: void(0);" name="top_a">这是顶部标签</a>
#                 <a href="#top_a">这是链接跳转到另一个链接</a> #相当于实现页面滚动的效果
#                 下面这种不会跳转
#                 <h2 name="h2_tag">这是测试啊</h2>
#                 <a href="#h2_tag">测试能不能跳转到h2标签</a>
#         - 若想实现跳转，需要像下面这样。同样id也适用于a标签
#                 <h2 id="h2_tag">这是测试啊</h2>
#                 <a href="#h2_tag">测试能不能跳转到h2标签</a>
#
#     - 3.邮箱超链接:使用mailto
#         - href="mailto:liutao@haha.com"
#
# ## 图片标签img
# - 作用：用于在页面中引入图片使用
# - 属性：
#     - src：图片地址：最好使用相对地址，./表示当前目前，../../表示上上层目录
#     - width，height属性
#         - 只设置一个值，自动等比缩放
#     - alt属性：图片加载失败显示的文字内容
#     - title属性：鼠标悬停时的提示文字
#         - 要求alt和title属性必须同时书写且内容一致
#     - border属性：设置图片的边框宽度属性
#
# ## 图像热点
# - 能够实现在一张图片上添加多种不同超链接效果的技术，需要使用到图片标签img，地图标签map，区域标签area
# - map标签：图像热点标签
#     - name属性：热点地图的名称
# - area标签：图像热点区域标签
#     - shape属性：设置热点区域的形状
#         - circle，rect，poly（多边形）
#     - coords属性：热点区域记录属性
#         - 用于记录绘制制定形状需要的参数
#         - circle就设置三个值，圆点坐标及半径r"100,100,50:
#         - rect:设置两个值，对角线就可以确定一个矩形
#         - poly：几边形就设置几个值
#     - href，设置热点区域的链接地址
#     - target属性
#
# ## 表格标签table
# - table标签属性：
#     - border:表格的宽度，单位像素
#     - width属性，设置表格的总宽度
#     - height：设置表格的总高度
#     - align:设置表格相对于外层标签的对其方式
#         - 值可以设定为left,center,right
#     - cellspace:设置单元格之间的间隙大小
#     - cellpadding:设置单元格中内容开始书写的位置
#     - bgcolor:表格的背景颜色
# - tr标签 table row用于定义表格的行
#     - align属性：单元格内内容的水平对齐方式
#         - left,center,right
#     - valigb属性：单元格内内容的垂直对齐方式
#         - top,middle,bottom
#     - width:设置单元格的宽度会影响一列的宽度
#     - colspan属性：单元格跨列设置
#     - rowspan属性：单元格跨行设置
# - td标签，列标签
# - th表头标签，与tr，td具有相同的属性和用法，th具有固定的样式：粗体字，居中对齐
# - caption：表格描述标签，相当于表格标题
# - 写表格时一般用thead标签和tbody将表头和主体分开，为了便于后期的样式修改
#
# ## 表单标签form
# - 用于连接用户和后台服务器的窗口，负责接收用户的数据和操作，将数据提交到后台服务器页面的标签
# - form标签： 设定信息即表单范围标签
# - 属性如下：
#     - action属性：设置当前表单数据提交的地址
#     - method属性：设置当前表单提交数据的方式
#         - get方式：使用明文传输，提交的数据长度有限
#         - post方式：不会明文显示在地址栏中，在head头信息中发送
#             - enctype属性：设置当前表单提交数据的编码方式
#                 - enctype为：application/x-www-from-urlencode时表示他就是url编码（默认值）
#                 - 为multipart/form-data:表示上传文件必须有值
#                 - 为text/plain:基本不编码
#     - target属性：值和a标签的href属性一样
#
#
# ### form下的内容
# - input标签：输入表单标签
#     - name:设置当前表单提交数据的名称，必须有
#     - value:设置当前表单的默认值或提示信息（推荐作为默认值使用）
#     - disable:禁用属性，该数据不会发送给浏览器
#     - readonly：只读
#     - checked:选择默认选项
#     - placeholder：做提示
#     - maxlength:输入数据的最大长度
#     - type：通过type属性定义不同类型的表单控件，此标签必须要加入name属性，否则提交会出错。type的值为以下：
#          - text:普通文本输入框，value属性表示默认值
#          - password:密码输入框，value属性表示默认值
#          - radio：单选按钮,必须要有name属性和value属性，且一组单选框name值必须相同。因为单选框和多选框无法输入内容，所以value是该复选框提交给后台程序传过去的值，所以必须要有value
#          - checkbox：多选按钮,必须指定name属性和value属性，并且一组多选框name属性的值要相同
#              - checked：默认选中
#
#          - file：文件上传选框，一般不写value
#          - textarea:文本域，不需要input引入
#          - submit:提交按钮，name不写value设置当前按钮提交的名称，和buttton提交效果一样。要放在表单域中才能正确提交
#          - reset：重置按钮，name可以不写，value为按钮名称
#          - hidden：隐藏域，要和表单一起提交的信息，不需要用户看见，name和value必须有
# - select下拉列表框，必须要配合option标签来使用
#     - select属性
#         - multiple:设定可以多选择几个值，按crtl键进行选择
#         - size:表示下拉每次呈现几个选择
#         - disabled：只要有disabled属性，浏览器就不会帮你发 送这个数据
#     - option选择项标签，属性：
#         - selected:默认选择的值
#         - value：提交的值
#             - 注意：如果option标签中不使用value属性，那么提交的时候会将option标签的text提交上去，不推荐这样
# - textarea 多行文本
#     -textarea name="" id="" cols="30" rows="10"
#     - 没有value属性，可在标签中间写，起提示作用
# - button 标签 多功能按钮标签
#     - type属性：
#         - 值可以为submit,reset,button(普通按钮)
#     - 小技巧：将文字和表格绑定起来
#         - 使用label标签
#         - <label for="man">男</label>：man是某个input标签的id
#
# ## form标签相关的属性
# - 尺寸相关的属性
#     - size属性：设置input标签的长度
#         - 主要用于input中的文本输入框和密码输入框，还可以用于多选列表
#     - cols属性：设置文本域的宽度
#     - rows属性：设置文本域的高度
#         - 主要用于textarea
# - 内容长度的属性
#     - maxlength：设置表单允许输入的最大字符数
#         - 主要用于input类型的文本输入框和密码输入框及文本域标签
# - 只读属性
#     - readonly：设置表单内容只可以查看不可以修改
#         - 适用于input类型中的文本输入框，密码输入框及文本域标签
# - 不可见属性：
#     - disabled:设置当前表单内容不会提交给服务器（服务器不可见）
#         - 设置disabled属性的表单不会提交，当前表单内容不可以修改，并且背景变为灰色
# - 选中属性
#     - checked:设置表单默认选中的项
#         - 适用于input标签的单选和复选框
#     - selected:设置表单默认选中的项
#         - 适用于select下拉列表
#
# ## form中其他内容
# - label标签：
#     - 为input表单添加标注，可以绑定文字和选项
# - fieldset标签：
#     - 为表单定义可见范围边框，同时可以配合legend添加标题
# - pre标签
#     - 能保存原始代码的格式，包括多个空格，但是需要将大于和小于括号替换为&lt;&gt;

# %% [markdown]
# # 框架和框架集
# - frameset是给后台布局使用的，前台不用
# - 框架集：当前页面完全由其他页面组成，当前页面没有自己的内容。该框架集不能与html，head等使用，是相冲突的
# - 1、frameset标签：框架集合标签
#     - 每一个页面中包含多个子页面，从而组成一个框架集合页面
#     - 属性：
#         - cols：纵向切割页面属性，值为多个数值组成，使用逗号分隔
#                 cols="40%,60%"纵向切割，左侧40%，右侧60%
#         - rows：横向切割页面属性，值为多个数值组成，使用逗号分隔
#                 rows="20%,80%"横向分割，顶部20%，底部80%
#         - frameborder：设置框架集合是否使用边框
#             - 1使用边框（默认使用），0不适用
#         - border：设置框架集合边框的粗细
#             - 值为像素值，不需要单位。只有frameborder值为1时才设置border属性
# - frameset下的frame标签：引入框架页面标签
#     - 在框架集合页面用于引入其他子页面使用。每个子页面是独立的，可以独立浏览
#     - 属性
#         - src属性：设置引入页面的地址
#         - noresize属性：禁止拖动页面属性
#         - scrolling属性：设置是否允许出现滚动条
#             - auto值：自动检测，如果内容超出高度就出现滚动条，否则就不出现
#             - no值：一直都不出
#             - yes值：一直都有滚动条，但不一定有滑块
#         - 注意：在框架集合中，不允许出现body标签或者body标签中的内容，否则就会出错。说白了就是不能出现text内容
#
# - 2、iframe标签，可以和html，head一起使用，为自己的HTML页面引入其他页面
#     - 属性
#         - src属性：设置引入页面的地址
#         - width:设置引入页面的宽度
#         - height：引入页面的高度
#         - noresize属性：禁止拖动页面属性
#         - scrolling属性：设置是否允许出现滚动条
#             - auto值：自动检测，如果内容超出高度就出现滚动条，否则就不出现
#             - no值：一直都不出
#             - yes值：一直都有滚动条，但不一定有滑块

# %% [markdown]
# # head头中的主要标签
# - title标签
#     - 用于定义当前页面的标题，会在浏览器的标签栏中显示
#     - title对网站的SEO优化有一定的影响
#     - 首页：一般设置为网站名称即可
#     - 内容页：当前页面的主要标题，频道等名称
#     - 频道列表页：当前频道名称
#     - 注意：title中可以出现当前网站的关键字，但是不要太多，不要重复，要精简
# - meta标签：对于浏览器进行设置的标签
#     - 1.设置浏览器的声明字符集
#         - meta http-equiv="content_type" content="text/html";charset="utf-8":这是html4的书写方式，HTML5直接就写一个charset就行
#     - 2.设置浏览器的刷新和跳转方式
#         - meta http-equiv="refresh" content="时间;url=地址" />
#     - 3.为搜索引擎进行的信息设置
#         - a.设置关键字
#             - meta name="keywords" content="关键字,关键字;.."
#             - 注意：关键字之间必须使用英文逗号分隔，字数尽量保持在60-80之间
#         - b.设置网址描述信息：即搜索引擎的页面信息介绍
#             - meta name="description" content="当前网站的描述，要使用通顺的语言"，140词左右
#         - c.设定作者
#             - meta name="author" content="作者名字"
#         - d.设置开发工具
#             - meta name="generator" content="开发工具信息"
#         - e.设置网站修订时间及作者
#             - meta name="revised" content="作者,时间"
# - base标签
#     - 基准连接标签
#     - 属性
#         - href属性：设置基准连接属性
#         - 注意：为页面中所有的相对链接添加href属性的值，组成一个新的绝对路径，对绝对路径不起作用
#         - target属性：设置连接的打开方式
#             - 注意：为页面中所有没有设置打开方式的链接，添加打开方式，主要设置了打开方式，就不会受到了该属性的影响
#
# - link标签：
#     - 用于在页面中引入css文件标签
#     - 属性
#         - href：设置引入css文件地址
#         - type：设置引入time的MIME类型，MIME是浏览器区分文件的标识，类似于文件后缀
#         - rel：设置引入文本和当前页面之间的关系，stylesheet样式表单
#         - 注意：rel属性和src属性天生冲突不能共存，所以link采用href来引入文件地址。引入css文件时，必须要把rel设置为stylesheet，type="text/css"
#         - link的其他用法：
#             - 设置标签栏的图标,图片要为ico格式
#                 - link rel="icon"/logo.ico type="image/x-iicon"

# %% [markdown]
# # 实体字符
# - 特殊符号
# - 大于>：	&gt;
# - 小于<：	&lt;
# - 空格:  @nbsp;
# - 引号"": @quot;
# - 版权号（就是一个圈里面包含一个c）：@copy;
# - x号，即关闭符号： @times;
# - &号；@amp;
#
# ## XHTML规范
# - 1.所有标签名必须使用小写字母
# - 2.所有标签必须闭合，单标签自封闭
# - 3.所有属性必须有值，单属性值为属性名disabled
# - 4.所有属性值必须使用双引号
# - 5.所有标签必须合理嵌套
# - 6.所有特殊字符必须使用实体字符表示
# - 7.所有img标签必须加alt属性
# - 8.所有注释内容中不允许出现-等信息，如果需要使用-，可以使用=代替
#
# ## 关于颜色的表示方式
# - 1.使用颜色英文单词
# - 2.RGB颜色表示模式: 三个数字表示 "255,255,255"
# - 3.16进制模式表示
#
# ## 长度单位
# - 像素，百分比
