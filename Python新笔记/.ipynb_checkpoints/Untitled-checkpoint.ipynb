# %% [markdown]
# ### 一、获取临时token
#
# ```apl
# @api {get} /external_use/construction_dispatch/get_token
# @apiParamExample {Array} 请求参数
# @apiParam     	{Int}        uid													OA系统用户ID
#
# @apiSuccessExample {Array} 返回数据
# @apiSuccess     {Str}        access_token									临时token，有效期1H
# 返回值类型: JSON
# {
# 		"message": "OK",
# 		"access_token": ""
# }
# ```
#
# ### 二、获取本站不同类别施工请销点详情
#
# ```apl
# @api {post} /external_use/construction_dispatch/cur_station_info
#
# @apiParamExample {Array} 请求参数
# @apiParam     {Dict}       params															参数
# @apiParam     {Str}        params.token												认证token
# @apiParam     {Str}        params.line_no											线别序号，如：六号线为6
# @apiParam     {Str}        params.station_name								      站点名称
# @apiParam     {List}       params.fields											查询的字段列表
# @apiParam     {Int}        params.limit												分页查询参数
# @apiParam     {Int}        params.offset											分页查询参数
# @apiParam     {Str}        params.sort												排序，默认逆序，如："id DESC"
# @apiParam     {Str}        params.day													查询日期，如：2020-11-23
# @apiParam     {Str}        params.work_category                查询的作业类别：有A1,A2,A3,C1,C2,others,默认是查询A123和C1
#
# @apiExample {Array} 参数示例
# {
#     "params": {
#         "token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiIsInR5cGUiOiJqd3QifQ.eyJ1aWQiOiJvYTEiLCJleHAiOjE2MzgyNjc1NTZ9.nQdEGex-f7yapoyJK7X89NlUf0ZPy1_FWq2_ybp4yhc",
#         "line_no": "2",
#         "station_name": "北大街站",
#         "fields": [
#             "construction_recognize_number",
#             "p_work_code",
#             "p_work_date_str",
#             "p_work_date",
#             "p_station_ask",
#             "work_time_line",
#             "work_time_line_end",
#             "p_principal",
#             "principal_name",
#             "show_start_pause",
#             "p_use_type",
#             "work_category_for_list",
#             "p_work_time",
#             "p_con_unit_name",
#             "p_work_content",
#             "work_area_summary_compute",
#             "elec_area_str",
#             "p_protect_measures",
#             "cooperate_content",
#             "principal_for_list",
#             "remark",
#             "cc_state",
#             "_task_definition_key",
#             "btns_str",
#             "plan_type",
#             "_back",
#             "ecs",
#             "p_outsource",
#             "_is_parallel",
#             "_level_role",
#             "_group",
#             "_compute_task_id",
#             "_compute_task_definition_key"
#         ],
#         "limit": 20,
#         "offset": 0,
#         "sort": "id ASC",
#         "day": "2020-03-03",
#         "work_category": ""
#     }
# }
#
#
#
# @apiSuccessExample {Array} 返回数据
# @apiSuccess     {List}       data															返回数据
# @apiSuccess     {Int}        data.id													施工计划id
# @apiSuccess     {Str}        data.construction_recognize_number				          施工承认号
# @apiSuccess     {Str}        data.p_work_code												作业代码
# @apiSuccess     {Str}        data.p_work_date												作业日期
# @apiSuccess     {Str}        data.p_station_ask												请点站点信息
# @apiSuccess     {Str}        data.work_time_line                             计划预计开始时间
# @apiSuccess     {Str}        data.work_time_line_end                          计划预计结束时间
# @apiSuccess     {List}        data.p_principal                施工负责人信息[名字，身份证，工号] ["赵红建","无","Q003472"]
# @apiSuccess     {Str}        data.p_use_type                         	     计划用途
#         返回值：construct(施工计划)/open(加开计划)
# @apiSuccess     {Str}        data.p_work_time												总作业时间
# @apiSuccess     {Str}        data.p_con_unit_name											施工单位
# @apiSuccess     {Str}        data.p_work_content											作业内容
# @apiSuccess     {Str}        data.p_protect_measures									    防护措施
# @apiSuccess     {Str}        data.remark													备注
# @apiSuccess     {Str}        data.cc_state													施工控制状态
#         返回值：('un_start', '未开始'),('recorded', '已登记'),('requesting', '请点中'),
#             ('requested', '已批点'),  ('canceled', '已取消'), ('finished', '已完成')
#             ('onrequesting', '已请点'),('near_line_requesting', '等待临线行调批点'),
#             ('near_line_requested', '临线行调已批点'),   ('constructing', '施工中'),
#             ('dispatch_reject', '行调驳回'),  ('protecting', '防护中'),
#             ('paused', '暂停中'),   ('delaying', '延点中'),   ('delay_reject', '延点被拒'),
#             ('construct_finish', '待销点')    ,('un_protecting', '撤销防护中'),
#             ('un_protected', '已撤销防护'),  ('protected', '已防护'),
#             ('un_requesting', '销点中'),   ('near_line_un_requesting', '等待临线行调销点'),
#             ('near_line_un_requested', '临线行调已销点'),,
# @apiSuccess     {Str}        data._compute_task_id										   任务id
# @apiSuccess     {Str}        data._compute_task_definition_key
# @apiSuccess     {Str}        data._task_definition_key								       任务key
# @apiSuccess     {Str}        data.plan_type														计划类型
#         返回值：month月计划 / week周计划/ day日计划 / temp临时补修计划/ emergency抢修计划/ ""配合计划
# @apiSuccess     {Bool}        data.p_outsource													外单位单选框
# @apiSuccess     {Bool}        data._is_parallel												并行任务中
# @apiSuccess     {Str}        data._level_role													阶段角色
# @apiSuccess     {Str}        data.p_work_date_str											作业日期
# @apiSuccess     {Bool}        data.show_start_pause										  是否显示开始暂停
# @apiSuccess     {Str}        data.work_category_for_list							      作业类别
# @apiSuccess     {Str}        data.work_area_summary_compute						        作业区域
# @apiSuccess     {Str}        data.elec_area_str												接触网供电安排
# @apiSuccess     {Str}        data.cooperate_content										   配合单位及内容
# @apiSuccess     {Str}        data.principal_for_list									   施工负责人
# @apiSuccess     {Str}        data.btns_str														操作按扭
# @apiSuccess     {Bool}        data._back														驳回任务
# @apiSuccess     {Str}        data.ecs														供电情况
#         返回值：none_electric（无要求），yes（带电），no（停电），no_electric_grand_line（停电挂地线），repeatedly_electric（反复停送电),如果是空值就当作无要求处理
# @apiSuccess     {Str}        data._group													群组
# @apiSuccess     {Str}        data.p_address_cancel                             销点地址
# @apiSuccess     {Str}        data.real_logout_time                             实际销点时间
# @apiSuccess     {Str}        data.real_login_time                              实际请点时间
#
#
# 返回值类型: JSON
# {
#     "jsonrpc": "2.0",
#     "id": null,
#     "result": {
#         "message": "OK",
#         "data": [
#             {
#                 "id": 433613,
#                 "construction_recognize_number": "无",
#                 "p_work_code": "2C1-03-02",
#                 "p_work_date": "2020-03-03",
#                 "p_station_ask": "北大街站",
#                 "work_time_line": "2020-03-04 00:45:00",
#                 "work_time_line_end": "2020-03-04 05:00:00",
#                 "p_principal": [
#                     "赵红建",
#                     "Q003472",
#                     "Q003472"
#                 ],
#                 "principal_name": "",
#                 "p_use_type": "construct",
#                 "p_work_time": "2020年3月3日 从次日0:45开始至5:00结束, 总耗时4小时15分钟",
#                 "p_con_unit_name": "机电二分部",
#                 "p_work_content": "EPS事故照明装置月检、半年检",
#                 "p_protect_measures": "现场防护",
#                 "remark": "需在0.4KV开关室断开相应电源开关",
#                 "cc_state": "finished",
#                 "_task_definition_key": "",
#                 "plan_type": "month",
#                 "p_outsource": false,
#                 "_is_parallel": false,
#                 "_level_role": "200-group_dispatch_duty",
#                 "p_work_date_str": "2020/03/03",
#                 "show_start_pause": false,
#                 "work_category_for_list": "C1",
#                 "work_area_summary_compute": "二号线,北大街站;",
#                 "elec_area_str": "无要求",
#                 "cooperate_content": "无",
#                 "principal_for_list": "赵红建,18717327596",
#                 "btns_str": "",
#                 "_back": false,
#                 "ecs": "none_electric",
#                 "_group": "",
#                 "_compute_task_id": "0b488535-5d8f-11ea-a0e0-0242ac110004",
#                 "_compute_task_definition_key": "",
#                 "real_logout_time": "2020-03-04 04:39:27",
#                 "real_login_time": "2020-03-04 00:53:53",
#                 "p_address_cancel": "北大街站"
#             }
#         ]
#     }
# }
# ```
#
# ### 三、获取施工区域含本站但请点地址非本站的施工计划
#
# ```apl
# @api {post} /external_use/construction_dispatch/get_correspond_plans
#
# @apiParamExample {Array} 请求参数
# @apiParam     {Dict}       params															参数
# @apiParam     {Str}        params.token												认证token
# @apiParam     {Str}        params.line_no											线别序号，如：六号线为6
# @apiParam     {Str}        params.station_name								  本站站点名称
# @apiParam     {List}       params.fields											查询的字段列表
# @apiParam     {Str}        params.day											  查询日期，如：2020-11-23
# @apiParam     {Str}        params.work_category                查询的作业类别：有A1,A2,A3,C1,C2,others,默认是查询A1A2A3和C1
# @apiParam     {Str}        params.target_station_name                    查询的主站站点名称，默认不传
#
# @apiExample {Array} 参数示例
# {
#     "params": {
#         "token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiIsInR5cGUiOiJqd3QifQ.eyJ1aWQiOiJvYTEiLCJleHAiOjE2MzgyNjc1NTZ9.nQdEGex-f7yapoyJK7X89NlUf0ZPy1_FWq2_ybp4yhc",
#         "line_no": "2",
#         "station_name": "北大街站",
#         "fields": [
#             "construction_recognize_number",
#             "p_work_code",
#             "p_work_date_str",
#             "p_work_date",
#             "p_station_ask",
#             "work_time_line",
#             "work_time_line_end",
#             "p_principal",
#             "principal_name",
#             "show_start_pause",
#             "p_use_type",
#             "work_category_for_list",
#             "p_work_time",
#             "p_con_unit_name",
#             "p_work_content",
#             "work_area_summary_compute",
#             "elec_area_str",
#             "p_protect_measures",
#             "cooperate_content",
#             "principal_for_list",
#             "remark",
#             "cc_state",
#             "_task_definition_key",
#             "btns_str",
#             "plan_type",
#             "_back",
#             "ecs",
#             "p_outsource",
#             "_is_parallel",
#             "_level_role",
#             "_group",
#             "_compute_task_id",
#             "_compute_task_definition_key"
#         ],
#         "limit": 20,
#         "offset": 0,
#         "sort": "id ASC",
#         "day": "2020-03-03",
#         "work_category": ""
#     }
# }
#
# @apiSuccessExample {Array} 返回数据
# @apiSuccess     {List}       data															返回数据
# @apiSuccess     {Int}        data.id													施工计划id
# @apiSuccess     {Str}        data.construction_recognize_number				          施工承认号
# @apiSuccess     {Str}        data.p_work_code												作业代码
# @apiSuccess     {Str}        data.p_work_date												作业日期
# @apiSuccess     {Str}        data.p_station_ask												请点站点信息
# @apiSuccess     {Str}        data.work_time_line                             计划预计开始时间
# @apiSuccess     {Str}        data.work_time_line_end                          计划预计结束时间
# @apiSuccess     {List}        data.p_principal                施工负责人信息[名字，身份证，工号] ["赵红建","无","Q003472"]
# @apiSuccess     {Str}        data.p_use_type                         	     计划用途
#         返回值：construct(施工计划)/open(加开计划)
# @apiSuccess     {Str}        data.p_work_time												总作业时间
# @apiSuccess     {Str}        data.p_con_unit_name											施工单位
# @apiSuccess     {Str}        data.p_work_content											作业内容
# @apiSuccess     {Str}        data.p_protect_measures									    防护措施
# @apiSuccess     {Str}        data.remark													备注
# @apiSuccess     {Str}        data.cc_state													施工控制状态
#         返回值：('un_start', '未开始'),('recorded', '已登记'),('requesting', '请点中'),
#             ('requested', '已批点'),  ('canceled', '已取消'), ('finished', '已完成')
#             ('onrequesting', '已请点'),('near_line_requesting', '等待临线行调批点'),
#             ('near_line_requested', '临线行调已批点'),   ('constructing', '施工中'),
#             ('dispatch_reject', '行调驳回'),  ('protecting', '防护中'),
#             ('paused', '暂停中'),   ('delaying', '延点中'),   ('delay_reject', '延点被拒'),
#             ('construct_finish', '待销点')    ,('un_protecting', '撤销防护中'),
#             ('un_protected', '已撤销防护'),  ('protected', '已防护'),
#             ('un_requesting', '销点中'),   ('near_line_un_requesting', '等待临线行调销点'),
#             ('near_line_un_requested', '临线行调已销点'),,
# @apiSuccess     {Str}        data._compute_task_id										   任务id
# @apiSuccess     {Str}        data._compute_task_definition_key
# @apiSuccess     {Str}        data._task_definition_key								       任务key
# @apiSuccess     {Str}        data.plan_type														计划类型
#         返回值：month月计划 / week周计划/ day日计划 / temp临时补修计划/ emergency抢修计划/ ""配合计划
# @apiSuccess     {Bool}        data.p_outsource													外单位单选框
# @apiSuccess     {Bool}        data._is_parallel												并行任务中
# @apiSuccess     {Str}        data._level_role													阶段角色
# @apiSuccess     {Str}        data.p_work_date_str											作业日期
# @apiSuccess     {Bool}        data.show_start_pause										  是否显示开始暂停
# @apiSuccess     {Str}        data.work_category_for_list							      作业类别
# @apiSuccess     {Str}        data.work_area_summary_compute						        作业区域
# @apiSuccess     {Str}        data.elec_area_str												接触网供电安排
# @apiSuccess     {Str}        data.cooperate_content										   配合单位及内容
# @apiSuccess     {Str}        data.principal_for_list									   施工负责人
# @apiSuccess     {Str}        data.btns_str														操作按扭
# @apiSuccess     {Bool}        data._back														驳回任务
# @apiSuccess     {Str}        data.ecs														供电情况
#         返回值：none_electric（无要求），yes（带电），no（停电），no_electric_grand_line（停电挂地线），repeatedly_electric（反复停送电),如果是空值就当作无要求处理
# @apiSuccess     {Str}        data._group													群组
# @apiSuccess     {Str}        data.p_address_cancel                             销点地址
# @apiSuccess     {Str}        data.real_logout_time                             实际销点时间
# @apiSuccess     {Str}        data.real_login_time                              实际请点时间
#
#
# {
#     "jsonrpc": "2.0",
#     "id": null,
#     "result": {
#         "message": "OK",
#         "data": [
#             {
#                 "id": 420816,
#                 "construction_recognize_number": "无",
#                 "p_work_code": "2A1-03-01",
#                 "p_work_date": "2020-03-03",
#                 "p_station_ask": "凤栖原站",
#                 "work_time_line": "2020-03-04 00:50:00",
#                 "work_time_line_end": "2020-03-04 03:30:00",
#                 "p_principal": [
#                     "肖玫",
#                     "Q004455",
#                     "Q004455"
#                 ],
#                 "p_use_type": "construct",
#                 "p_work_time": "2020年3月3日 从次日0:50开始至3:30结束, 总耗时2小时40分钟",
#                 "principal_name": "",
#                 "p_con_unit_name": "站务二分部",
#                 "p_work_content": "二号线电话闭塞法演练",
#                 "p_protect_measures": "现场防护",
#                 "remark": "客运一部提前36小时向调度一部、车辆一部、通号一部、乘务一部提供演练方案，作业前行调按照演练方案视情况组织电客车到正线车站待令。",
#                 "cc_state": "un_start",
#                 "_task_definition_key": "",
#                 "plan_type": "month",
#                 "p_outsource": false,
#                 "_is_parallel": false,
#                 "_level_role": "551-group_dispatch_dep_mg",
#                 "p_work_date_str": "2020/03/03",
#                 "show_start_pause": false,
#                 "work_category_for_list": "A1",
#                 "work_area_summary_compute": "二号线,渭河出入段线至潏河出入场线上下行线及其辅助线",
#                 "elec_area_str": "(2A2至2A11,2B2至2B11,2C1A,2C1B,2C2至2C4,2C5A,2C5B)供电分区;渭河车辆段(2D2,2D3,)供电分区潏河停车场(2T1,2T3,)供电分区带电：",
#                 "cooperate_content": "乘务二分部(乘务一部提供2名司机);通号二分部( 通号二分部负责在销点前将联锁站道岔恢复正常状态);检修二分部( 车辆一部提供2列电客车)",
#                 "principal_for_list": "肖玫,18049187032",
#                 "btns_str": "",
#                 "_back": false,
#                 "ecs": "yes",
#                 "_group": "",
#                 "_compute_task_id": "12d08fae-4cae-11ea-a0e0-0242ac110004",
#                 "_compute_task_definition_key": "",
#                 "real_logout_time": "",
#                 "real_login_time": "",
#                 "p_address_cancel": "无"
#             }
#         ]
#     }
# }
#
# ### 四、人脸识别信息提交
# ```apl
# @api {post} /external_use/construction_dispatch/sync_face_info
#
# @apiParamExample {Array} 获取数据
# @apiParam     {Int}        params.plan_id													施工计划ID
# @apiParam     {Str}        params.face_id													人脸识别ID
# @apiParam     {Int}        params.token														token
# {
#     "params": {
#         "plan_id": 803034,
#         "face_id": "Q006458",
#         "token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiIsInR5cGUiOiJqd3QifQ.eyJ1aWQiOiIzMzMzMzMiLCJleHAiOjE2MDgwODQwNzZ9.cVr7PC6MVrjsqD0u4f05cUrp973Ft5MCuGzJFmUh4Ds"
#     }
# }
#
# @apiSuccessExample {Array} 返回数据
# 返回值类型: JSON
# {
#     "jsonrpc": "2.0",
#     "id": 11111,
#     "result": {
#         "message": "",
#         "response": "OK"
#     }
# }
# ```

# %%
a = ""
if not a:
    print("a")
# Out:
# a
