# %% [markdown]
# # field widget
#
# ## decorations
# - 修饰记录的样式
#         decoration-bf
#
#         decoration-it
#
#         decoration-danger
#
#         decoration-info
#
#         decoration-muted
#
#         decoration-primary
#
#         decoration-success
#
#         decoration-warning
#
# ## integer
# - 可用选项有：type(一般设置为number), step步长, format，是否格式化
#     - options='{"type": "number", "step": 100, "format": flase}'
#
# ## float
# - 属性有：digits：digits="[42,5]"
# - 可用选项有：type， step， step
#
# ## float_time
# - 这个小部件的目标是正确地显示一个表示时间间隔(以小时为单位)的浮点值。因此，例如，0.5应该被格式化为0:30，或4.75对应于4:45。
# - float类型字段可用
#
# ## float_factor
# - 这个小部件的目标是正确地显示一个浮点值，该浮点值使用其选项中给定的因子转换。例如，数据库中保存的值是0.5，而因子是3，那么小部件的值应该格式化为1.5。
# - 因子在options中进行定义
# - float可用
#
# ## float_toggle
# - 每次点击都允许用户在范围内循环。这里的目的是将字段值限制为预定义的选择。也支持因子转换
# - <field name="days_to_close" widget="float_toggle" options='{"factor": 2, "range": [0, 4, 8]}'/>
#
# ## boolean
# - 将该字段设置为布尔类型
#
# ## char
# - 默认都是这个类型
#
# ## date
# - 将其设置为date类型
# - Date，Datetime字段可用
# - 支持datepicker选项，详见：https://github.com/Eonasdan/tempus-dominus
# - <field name="datefield" options='{"datepicker": {"daysOfWeekDisabled": [0, 6]}}'/>
#
# ## Datetime
# - 将其设置为Datetime类型
# - Date，Datetime字段可用
#
# ## daterange
# - 这个小部件允许用户在单个选择器中选择开始和结束日期。
# - 可用选项有：
#     - related_start_date, 应用于结束日期字段以获取开始日期值，该值用于在选择器中显示范围。
#              field name="start_date" widget="daterange" options='{"related_end_date": "end_date"}'/
#     - related_end_date,
#     - picker_options: picker的额外设置
# - Date，Datetime字段可用
#
# ## remaining_days
# - 目标日期值与（即字段的值）与今天日期值相差的天数，只读
# - Date，Datetime字段可用
#
# ## monetary
# - 金钱
# -  monetary, float字段可用
#
# ## text
# - 文本
# - Text字段
#
# ## handle
# - 该字段的工作将显示为一个句柄，并允许通过拖放各种记录来重新排序
# - int字段可用
#
# ## email,phone,url
# - field name="foo" widget="url" text="Some URL"/
#
# ## domain
# - 是一个静态的domain，还不知道干啥，它对应的字段就是一个domain字段
#
# ## link_button
# - 将他变为一个链接,该链接是可点击的，并将打开一个新的浏览器窗口，其值为url
#
# ## image
# - 将Binary字段转化为图片形式
#
# ## binary
#
# ## priority
# - 这个小部件呈现为一组星星，允许用户单击它来选择值或不选择值。这是有用的，例如标记一个任务为高优先级。
# - Selection字段可用
#
# ## attachment_image
# - 用来查看图像
# - many2one字段可用
#
# ## image_selection
# - 允许用户通过单击图像来选择一个值。
#         <field name="external_report_layout" widget="image_selection" options="{
#             'background': {
#                 'image_link': '/base/static/img/preview_background.png',
#                 'preview_link': '/base/static/pdf/preview_background.pdf'
#             },
#             'standard': {
#                 'image_link': '/base/static/img/preview_standard.png',
#                 'preview_link': '/base/static/pdf/preview_standard.pdf'
#             }
#         }"/>
# - Selection可用
#
# ## label_selection
# - 用来加载一些提示信息，他不可编辑
# - Selection可用
#
# ## state_selection
# - 这是一个专门的选择小部件。它假设记录有一些硬编码的字段，存在于视图中:stage_id, legend_normal, legend_blocked, legend_done。这主要用于显示和更改项目中任务的状态，下拉列表中还显示了其他信息。
# - Selection可用
#
# - 更多详见：https://www.odoo.com/documentation/14.0/developer/reference/javascript/javascript_reference.html#field-widgets
#
# ## many2one
# - Attributes:
#
#     - can_create: allow the creation of related records (take precedence over no_create option)
#
#     - can_write: allow the editing of related records (default: true)
#
# - Options:
#
#     - no_create: prevent the creation of related records
#
#     - quick_create: allow the quick creation of related records (default: true)
#
#     - no_quick_create: prevent the quick creation of related records (don’t ask me)
#
#     - no_create_edit: same as no_create, maybe…
#
#     - create_name_field: when creating a related record, if this option is set, the value of the create_name_field will be filled with the value of the input (default: name)
#
#     - always_reload: boolean, default to false. If true, the widget will always do an additional name_get to fetch its name value. This is used for the situations where the name_get method is overridden (please do not do that)
#
#     - no_open: boolean, default to false. If set to true, the many2one will not redirect on the record when clicking on it (in readonly mode)
#
# ## list.many2one
# - 将该many2one字段渲染为一个text文本，不允许打开相关联的记录
#
# ## many2one_barcode
# - 允许从移动设备(Android/iOS)打开摄像头扫描条形码。
#
# ## many2many (FieldMany2Many)
# - Attributes:
#
#     - mode: string, default view to display
#
#     - domain: restrict the data to a specific domain
#
# - Options:
#
#     - create_text: allow the customization of the text displayed when adding a new record
#
#     - link: domain determining whether or not records can be added to the relation (default: True).
#
#     - unlink: domain determining whether or not records can be removed from the relation (default: True).
#
# ## many2mant_tags
# - 可用选项：create,color_field(一个数字字段，根据它的值可以决定使用什么颜色),no_edit_color(表示不能编辑颜色)
# - {color_field: 'yellow'}
#
#
# ## many2many_checkboxes
# - This field displays a list of checkboxes and allows the user to select a subset of the choices. Note that the number of displayed values is limited to 100. This limit isn’t customizable. It simply allows to handle extreme cases where this widget is wrongly set on a field with a huge comodel. In those cases, a list view is more adequate as it allows pagination and filtering.

# %%
record = [i for i in range(50)]
if record:
    for i in range(1, len(record), 20):
        userid_list = []
        if i + 20 > len(record):
            for u in range(i, len(record)):
                userid_list.append(record[u])
        else:
            for u in range(i, i + 20):
                userid_list.append(record[u])
print(userid_list)
# Out:
# 10
# [41, 42, 43, 44, 45, 46, 47, 48, 49]

# %%
a = '2'
print(format(a, "0>4"))
# Out:
# 0002
