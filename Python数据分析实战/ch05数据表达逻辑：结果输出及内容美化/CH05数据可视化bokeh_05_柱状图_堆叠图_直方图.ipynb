# %%
'''
【课程5.6】  柱状图/堆叠图/直方图

① 单系列柱状图
② 多系列柱状图
③ 堆叠图
④ 直方图

'''

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

import warnings
warnings.filterwarnings('ignore') 
# 不发出警告

from bokeh.io import output_notebook
output_notebook()
# 导入notebook绘图模块

from bokeh.plotting import figure,show
from bokeh.models import ColumnDataSource
# 导入图表绘制、图标展示模块
# 导入ColumnDataSource模块
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8a7aa4aa-7850-40dd-8acf-a35c35385bb1">Loading BokehJS ...</span>
#     </div>

# %%
# 1、单系列柱状图
# vbar

p = figure(plot_width=400, plot_height=400)
p.vbar(x=[1, 2, 3], width=0.5, bottom=0,top=[1.2, 2.5, 3.7],  # x：横轴坐标，width：宽度，bottom：底高度，top：顶高度
       #color = ['red','blue','green'], alpha = 0.8   # 整体颜色设置，也可单独设置 → color="firebrick"
       line_width = 1,line_alpha = 0.8,line_color = 'black', line_dash = [5,2],    # 单独设置线参数
       fill_color = 'red',fill_alpha = 0.6    # 单独设置填充颜色参数
      )
# 绘制竖向柱状图

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="93650724-a9cc-4afa-9272-6e14b4cfef05"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("93650724-a9cc-4afa-9272-6e14b4cfef05");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("93650724-a9cc-4afa-9272-6e14b4cfef05");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '93650724-a9cc-4afa-9272-6e14b4cfef05' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fd447acb-26f2-42de-8468-27b8f0982566":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"red"},"line_alpha":{"value":0.8},"line_dash":[5,2],"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"f438faf1-a25b-47ea-a4b5-d4e1d0f7db39","type":"VBar"},{"attributes":{},"id":"c3e0934f-87d8-4caa-921c-409b97179049","type":"SaveTool"},{"attributes":{},"id":"4bc0b37e-e7a8-4a38-8491-aa0d3f24467b","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["top","x"],"data":{"top":[1.2,2.5,3.7],"x":[1,2,3]}},"id":"f0a3ad9f-0a96-4bf9-8bd6-57ad1d08bef3","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"b0b48b95-43db-43fc-b706-ac975dc400b7","type":"BoxAnnotation"}},"id":"21dd409b-df99-40dd-bf9a-3406772f597c","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"d188b796-8ff0-44b0-859c-fe609e15c0a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"15c4ec50-00de-46ce-ae2a-a2f88c991c22","type":"BasicTicker"}},"id":"0cccb763-5f65-4842-b4d5-4b248fd1bf88","type":"Grid"},{"attributes":{"source":{"id":"f0a3ad9f-0a96-4bf9-8bd6-57ad1d08bef3","type":"ColumnDataSource"}},"id":"c98ffd8f-fefc-489e-b8d2-2de6f4e25e54","type":"CDSView"},{"attributes":{},"id":"15c4ec50-00de-46ce-ae2a-a2f88c991c22","type":"BasicTicker"},{"attributes":{},"id":"3a495aff-0acf-49ed-b38e-c58eba07467c","type":"LinearScale"},{"attributes":{"formatter":{"id":"4bc0b37e-e7a8-4a38-8491-aa0d3f24467b","type":"BasicTickFormatter"},"plot":{"id":"d188b796-8ff0-44b0-859c-fe609e15c0a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc5aa3cf-d81d-45a6-b6c3-bfbb97be4f20","type":"BasicTicker"}},"id":"4e9ca2e6-f92e-41bf-b40b-6f9862e20922","type":"LinearAxis"},{"attributes":{"plot":{"id":"d188b796-8ff0-44b0-859c-fe609e15c0a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc5aa3cf-d81d-45a6-b6c3-bfbb97be4f20","type":"BasicTicker"}},"id":"b446da51-612c-4bff-8743-05cfdf4bfd9f","type":"Grid"},{"attributes":{"data_source":{"id":"f0a3ad9f-0a96-4bf9-8bd6-57ad1d08bef3","type":"ColumnDataSource"},"glyph":{"id":"f438faf1-a25b-47ea-a4b5-d4e1d0f7db39","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":
"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"4b60cb42-5362-489d-897c-4d9ee4396ee4","type":"HBar"},{"attributes":{"callback":null},"id":"9e6f939e-1bac-4406-8448-4ce68de2accd","type":"DataRange1d"},{"attributes":{},"id":" ...

# %%
# 1、单系列柱状图 - 分类设置标签
# ColumnDataSource

from bokeh.palettes import Spectral6
from bokeh.transform import factor_cmap
# 导入相关模块

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]
source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))
colors = [ "salmon", "olive", "darkred", "goldenrod", "skyblue", "orange"]
# 创建一个包含标签的data，对象类型为ColumnDataSource

p = figure(x_range=fruits, y_range=(0,9), plot_height=350, title="Fruit Counts",tools="")

p.vbar(x='fruits', top='counts', source=source,    # 加载数据另一个方式
       width=0.9, alpha = 0.8,
       color = factor_cmap('fruits', palette=Spectral6, factors=fruits),    # 设置颜色
       legend="fruits")
# 绘制柱状图，横轴直接显示标签
# factor_cmap(field_name, palette, factors, start=0, end=None, nan_color='gray')：颜色转换模块，生成一个颜色转换对象
# field_name：分类名称
# palette：调色盘
# factors：用于在调色盘中分颜色的参数
# 参考文档：http://bokeh.pydata.org/en/latest/docs/reference/transform.html

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
# 其他参数设置

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4e1b5fb4-84f1-4061-bdf2-fb6f9669badf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("4e1b5fb4-84f1-4061-bdf2-fb6f9669badf");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4e1b5fb4-84f1-4061-bdf2-fb6f9669badf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4e1b5fb4-84f1-4061-bdf2-fb6f9669badf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3fe785a0-6f51-4962-9a6f-64bbc4fa16ce":{"roots":{"references":[{"attributes":{"factors":["Apples","Pears","Nectarines","Plums","Grapes","Strawberries"],"palette":["#3288bd","#99d594","#e6f598","#fee08b","#fc8d59","#d53e4f"]},"id":"50d122f2-8161-435a-bf7d-9bad77c7089e","type":"CategoricalColorMapper"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"6be87932-fe63-4b5d-8273-b4be0e6f81de","subtype":"Figure","type":"Plot"},"ticker":{"id":"c2467536-3e10-41aa-ab3b-78aeb22652dd","type":"CategoricalTicker"}},"id":"e3813f9e-4436-4f22-a40e-5a5be9f03f09","type":"Grid"},{"attributes":{"source":{"id":"e7c26646-c125-43dd-bf45-c9d5492498fa","type":"ColumnDataSource"}},"id":"206efa47-c976-4720-a39c-c10f90b4fccf","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"counts"},"width":{"value":0.9},"x":{"field":"fruits"}},"id":"3594ddab-7c40-4d6e-bc79-834a7cb8e21d","type":"VBar"},{"attributes":{},"id":"c2467536-3e10-41aa-ab3b-78aeb22652dd","type":"CategoricalTicker"},{"attributes":{"dimension":1,"plot":{"id":"6be87932-fe63-4b5d-8273-b4be0e6f81de","subtype":"Figure","type":"Plot"},"ticker":{"id":"a5506dd7-0da3-4908-b407-ac733d4011a7","type":"BasicTicker"}},"id":"e1dc6156-c616-4ed7-aafa-57c3623696cf","type":"Grid"},{"attributes":{"formatter":{"id":"0406c431-6c44-4437-9115-d20944e77ca3","type":"BasicTickFormatter"},"plot":{"id":"6be87932-fe63-4b5d-8273-b4be0e6f81de","subtype":"Figure","type":"Plot"},"ticker":{"id":"a5506dd7-0da3-4908-b407-ac733d4011a7","type":"BasicTicker"}},"id":"12b1a9cd-4795-4974-9bcb-ac9d774477a9","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Fruit Counts"},"id":"be620cbf-d999-4791-a62b-ce08bcb790d4","type":"Title"},{"attributes":{"label":{"field":"fruits"},"renderers":[{"id":"9749d1bc-db49-46cd-afc5-b550535c83fc","type":"GlyphRenderer"}]},"id":"8c31bf8b-6663-4b79-93ac-5f2782705ad3","type":"LegendItem"},{"attributes":{"below":[{"id":"244a7fb8-1d90-460d-aaac-294f209b619a","type":"CategoricalAxis"}],"left":[{"id":"12b1a9cd-4795-4974-9bcb-ac9d774477a9","type":"LinearAxis"}],"plot_height":350,"renderers":[{"id":"244a7fb8-1d90-460d-aaac-294f209b619a","type":"CategoricalAxis"},{"id":"e3813f9e-4436-4f22-a40e-5a5be9f03f09","type":"Grid"},{"id":"12b1a9cd-4795-4974-9bcb-ac9d774477a9","type":"LinearAxis"},{"id":"e1dc6156-c616-4ed7-aafa-57c3623696cf","type":"Grid"},{"id":"0b49c3df-08c3-47c0-bd44-8668a376fb4f","type":"Legend"},{"id":"9749d1bc-db49-46cd-afc5-b550535c83fc","type":"GlyphRenderer"}],"title":{"id":"be620cbf-d999-4791-a62b-ce08bcb790d4","type":"Title"},"toolbar":{"id":"1e1c79ef-5d6f-4c7c-953c-09275c4a374f","type":"Toolbar"},"x_range":{"id":"03784608-9f8f-4c2d-812f-f25aa66591c8","type":"FactorRange"},"x_scale":{"id":"ee34bb72-9880-4f29-bb81-0efc6ea74f42","type":"CategoricalScale"},"y_range":{"id":"a9cc0030-86fc-4412-9b0f-9c56ba32b5d2","type":"Range1d"},"y_scale":{"id":"b79729ab-dfe5-43c7-b30e-fdbaf1f86ad7","type":"LinearScale"}},"id":"6be87932-fe63-4b5d-8273-b4be0e6f81de","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"factors":["Apples","Pears","Nectarines","Plums","Grapes","Strawberries"]},"id":"03784608-9f8f-4c2d-812f-f25aa66591c8","type":"FactorRange"},{"attributes":{},"id":"0406c431-6c44-4437-9115-d20944e77ca3","type":"BasicTickFormatter"},{"attributes":{},"id":"b79729ab-dfe5-43c7-b30e-fdbaf1f86ad7","type":"LinearScale"},{"attributes":{"formatter":{"id":"f86bbfde-fa7e-433b-89ae-2fbf6cc5ecc5","type":"CategoricalTickFormatter"},"plot":{"id":"6be87932-fe63-4b5d-8273-b4be0e6f81de","subtype":"Figure","type":"Plot"},"ticker":{"id":"c2467536-3e10-41aa-ab3b-78aeb22652dd","type":"CategoricalTicker"}},"id":"244a7fb8-1d90-460d-aaac-294f209b619a","type":"CategoricalAxis"},{"attributes":{"callback":null,"end":9},"id":"a9cc0030-86fc-4412-9b0f-9c56ba32b5d2","type":"Range1d"},{"attributes":{"callback":null,"column_names":["counts","fruits"],"data":{"counts":[5 ...

# %%
# 2、多系列柱状图
# vbar

from bokeh.transform import dodge
from bokeh.core.properties import value
# 导入dodge、value模块

df = pd.DataFrame({'2015':[2, 1, 4, 3, 2, 4],'2016':[5, 3, 3, 2, 4, 6], '2017':[3, 2, 4, 4, 5, 3]},
                 index = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries'])
# 创建数据

fruits = df.index.tolist()   # 横坐标
years = df.columns.tolist()    # 系列名
data = {'index':fruits}
for year in years:
    data[year] = df[year].tolist()
print(data)
# 生成数据，数据格式为dict

source = ColumnDataSource(data=data)
# 将数据转化为ColumnDataSource对象

p = figure(x_range=fruits, y_range=(0, 10), plot_height=350, title="Fruit Counts by Year",tools="")

p.vbar(x=dodge('index', -0.25, range=p.x_range), top='2015', width=0.2, source=source,color="#c9d9d3", legend=value("2015"))
p.vbar(x=dodge('index',  0.0,  range=p.x_range), top='2016', width=0.2, source=source,color="#718dbf", legend=value("2016"))
p.vbar(x=dodge('index',  0.25, range=p.x_range), top='2017', width=0.2, source=source,color="#e84d60", legend=value("2017"))
# 绘制多系列柱状图
# dodge(field_name, value, range=None) → 转换成一个可分组的对象，value为元素的位置（配合width设置）
# value(val, transform=None) → 按照年份分为dict

p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"
# 其他参数设置

show(p)
# Out:
# {'2015': [2, 1, 4, 3, 2, 4], 'index': ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries'], '2016': [5, 3, 3, 2, 4, 6], '2017': [3, 2, 4, 4, 5, 3]}
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="307c4cdc-8831-4573-a87b-cd6874f0bfb5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("307c4cdc-8831-4573-a87b-cd6874f0bfb5");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("307c4cdc-8831-4573-a87b-cd6874f0bfb5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '307c4cdc-8831-4573-a87b-cd6874f0bfb5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5ef71ff6-85ee-4bb1-a38b-bffb300dc925":{"roots":{"references":[{"attributes":{"data_source":{"id":"fe405f22-1caf-4e9a-920e-b0f8513e89c3","type":"ColumnDataSource"},"glyph":{"id":"1cba0e81-d845-44e8-8242-8518853e952c","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dc7a8e18-f1a7-46c3-a71a-6fb25d197319","type":"VBar"},"selection_glyph":null,"view":{"id":"d6f27e89-d462-4ef0-b69e-14823ff06682","type":"CDSView"}},"id":"99864fcf-5d53-4dbd-9dcc-da161400f718","type":"GlyphRenderer"},{"attributes":{"label":{"value":"2015"},"renderers":[{"id":"99864fcf-5d53-4dbd-9dcc-da161400f718","type":"GlyphRenderer"}]},"id":"ccb54b6f-16bf-4577-a4b7-2b40e7a6e982","type":"LegendItem"},{"attributes":{"source":{"id":"fe405f22-1caf-4e9a-920e-b0f8513e89c3","type":"ColumnDataSource"}},"id":"f207e4a1-1778-40cd-969f-634f47cb6baf","type":"CDSView"},{"attributes":{"range":{"id":"f0720580-c15f-4137-bcff-6d54ea82e3d3","type":"FactorRange"},"value":0.25},"id":"18dbe003-9af8-466c-a9b4-66a73ddcbc1d","type":"Dodge"},{"attributes":{"callback":null,"column_names":["2015","index","2016","2017"],"data":{"2015":[2,1,4,3,2,4],"2016":[5,3,3,2,4,6],"2017":[3,2,4,4,5,3],"index":["Apples","Pears","Nectarines","Plums","Grapes","Strawberries"]}},"id":"fe405f22-1caf-4e9a-920e-b0f8513e89c3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"2017"},"width":{"value":0.2},"x":{"field":"index","transform":{"id":"18dbe003-9af8-466c-a9b4-66a73ddcbc1d","type":"Dodge"}}},"id":"b1adb368-6485-44e4-9f3d-8bc88dd21090","type":"VBar"},{"attributes":{"label":{"value":"2017"},"renderers":[{"id":"5ab7b0f8-cad0-4fc7-8fe7-a1bec27f07b6","type":"GlyphRenderer"}]},"id":"61b62bfd-9816-4551-9436-8234d7b99784","type":"LegendItem"},{"attributes":{"source":{"id":"fe405f22-1caf-4e9a-920e-b0f8513e89c3","type":"ColumnDataSource"}},"id":"d6f27e89-d462-4ef0-b69e-14823ff06682","type":"CDSView"},{"attributes":{"callback":null,"factors":["Apples","Pears","Nectarines","Plums","Grapes","Strawberries"]},"id":"f0720580-c15f-4137-bcff-6d54ea82e3d3","type":"FactorRange"},{"attributes":{"data_source":{"id":"fe405f22-1caf-4e9a-920e-b0f8513e89c3","type":"ColumnDataSource"},"glyph":{"id":"41aee3f3-a10a-4d68-a917-7e3048c5bce9","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7d5cd7eb-ccc2-45fa-b660-1529a451c98d","type":"VBar"},"selection_glyph":null,"view":{"id":"5022ddd3-e6a2-4816-a0e9-9f5026298631","type":"CDSView"}},"id":"2a6284cb-9ff6-49ed-a951-18da09f652f4","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":10},"id":"e70e86fd-55da-4bc9-899a-d03192c12a67","type":"Range1d"},{"attributes":{"fill_color":{"value":"#718dbf"},"line_color":{"value":"#718dbf"},"top":{"field":"2016"},"width":{"value":0.2},"x":{"field":"index","transform":{"id":"bda0adf5-c672-4053-8d93-c7453e8e522c","type":"Dodge"}}},"id":"41aee3f3-a10a-4d68-a917-7e3048c5bce9","type":"VBar"},{"attributes":{"fill_color":{"value":"#e84d60"},"line_color":{"value":"#e84d60"},"top":{"field":"2017"},"width":{"value":0.2},"x":{"field":"index","transform":{"id":"18dbe003-9af8-466c-a9b4-66a73ddcbc1d","type":"Dodge"}}},"id":"2f28755c-d321-4906-9567-38576840c89f","type":"VBar"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto"},"id":"419d7d99-f2b8-48ef-adb2-3ba9b05be4c5","type":"Toolbar"},{"attributes":{"below":[{"id":"014bcb20-0aa8-431f-9d2b-bd3e278266e1","type":"CategoricalAxis"}],"left":[{"id":"3ca4228f-757d-42a8-9cfb-08b641a9f7f6","type":"LinearAxis"}],"plot_height":350,"renderers":[{"id":"014bcb20-0aa8-431f-9d2b-bd3e278266e1","type":"CategoricalAxis"},{"id":"d67a052f-99b4-4139-8f4c-a319554f9361","type":"Grid"},{"id":"3ca4228f-757d-42a8-9cfb-08b641a9f7f6","type":"LinearAxis"},{"id":"159bdfb4-096a-4c78-b757-eedbd3cf3821","type":"Grid"},{"id":"edb1aaed-b68d-4028-9669-40ace758c754","type":"Legen ...

# %%
# 3、堆叠图

from bokeh.core.properties import value
# 导入value模块

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ["2015", "2016", "2017"]
colors = ["#c9d9d3", "#718dbf", "#e84d60"]
data = {'fruits' : fruits,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 4, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}
source = ColumnDataSource(data=data)
# 创建数据

p = figure(x_range=fruits, plot_height=350, title="Fruit Counts by Year",tools="")
renderers = p.vbar_stack(years,          # 设置堆叠值，这里source中包含了不同年份的值，years变量用于识别不同堆叠层
                         x='fruits',     # 设置x坐标
                         source=source,
                         width=0.9, color=colors,
                         legend=[value(x) for x in years], name=years)
# 绘制堆叠图
# 注意第一个参数需要放years

p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"
# 设置其他参数

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d5a254e7-dd5e-418e-aaa4-f9ae38dd14c0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d5a254e7-dd5e-418e-aaa4-f9ae38dd14c0");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d
},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto"},"id":"a041fdeb-def8-47e2-a143-d1f7df3f7eee","type":"Toolbar"},{"attributes":{},"id":"5ae1e692-9e52-4464-a9f9-71d40bc2c3a5","type":"CategoricalTickFormatter"},{"attributes":{"data_source":{"id":"36271b03-fc31-48dd-bb24-bf70fb414bef","type":"ColumnDataSource"},"glyph":{"id":"e7ecc41b-358f-4e87-b642-4f928f559edc","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"name":"2017","nonselection_glyph":{"id":"7336fe53-aba7-41ce-8997-96e31ab6f290","type":"VBar"},"selection_glyph":null,"view":{"id":"c088a5c0-3908-4759-ab44-e2de877f2b68","type":"CDSView"}},"id":"d0903e35-7485-4fa1-b4fc-574848484e10","type":"GlyphRenderer"},{"attributes":{"source":{"id":"36271b03-fc31-48dd-bb24-bf70fb414bef","type":"ColumnDataSource"}},"id":"c088a5c0-3908-4759-ab44-e2de877f2b68","type":"CDSView"},{"attributes":{"bottom":{"expr":{"id":"5b5b17f3-d771-4aff-b3cf-2438e5c22d57","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"0f13692c-297f-43f2-9ed7-a9811d18dbbb","type":"Stack"}},"width":{"value":0.9},"x":{"field":"fruits"}},"id":"0e1d3a47-4aa3-4ea9-8811-a56c049d20b5","type":"VBar"},{"attributes":{"fields":["2015"]},"id":"6db74d6f-7687-4239-b835-5bac3410424c","type":"Stack"},{"attributes":{}, ...

# %%
# 3、堆叠图

from bokeh.palettes import GnBu3, OrRd3
# 导入颜色模块

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ["2015", "2016", "2017"]
exports = {'fruits' : fruits,
           '2015'   : [2, 1, 4, 3, 2, 4],
           '2016'   : [5, 3, 4, 2, 4, 6],
           '2017'   : [3, 2, 4, 4, 5, 3]}
imports = {'fruits' : fruits,
           '2015'   : [-1, 0, -1, -3, -2, -1],
           '2016'   : [-2, -1, -3, -1, -2, -2],
           '2017'   : [-1, -2, -1, 0, -2, -2]}

p = figure(y_range=fruits, plot_height=350, x_range=(-16, 16), title="Fruit import/export, by year")

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3, source=ColumnDataSource(exports),
             legend=["%s exports" % x for x in years])      # 绘制出口数据堆叠图

p.hbar_stack(years, y='fruits', height=0.9, color=OrRd3, source=ColumnDataSource(imports),
             legend=["%s imports" % x for x in years])      # 绘制进口数据堆叠图，这里值为负值

p.y_range.range_padding = 0.2     # 调整边界间隔
p.ygrid.grid_line_color = None   
p.legend.location = "top_left"
p.axis.minor_tick_line_color = None
p.outline_line_color = None
# 设置其他参数

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b3ef5aba-6547-4177-8d9d-fbae264df9a7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("b3ef5aba-6547-4177-8d9d-fbae264df9a7");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b3ef5aba-6547-4177-8d9d-fbae264df9a7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b3ef5aba-6547-4177-8d9d-fbae264df9a7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f1daa7af-5a06-4420-a63c-52dafd0fa309":{"roots":{"references":[{"attributes":{"fields":[]},"id":"d97f5e7d-52ef-4d66-8a07-6125673b04e7","type":"Stack"},{"attributes":{"callback":null,"column_names":["2016","2015","fruits","2017"],"data":{"2015":[-1,0,-1,-3,-2,-1],"2016":[-2,-1,-3,-1,-2,-2],"2017":[-1,-2,-1,0,-2,-2],"fruits":["Apples","Pears","Nectarines","Plums","Grapes","Strawberries"]}},"id":"910be62f-4757-4626-820b-7a424840e992","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":
# %%
# 4、直方图
# np.histogram + figure.quad()
# 不需要构建ColumnDataSource对象

df = pd.DataFrame({'value': np.random.randn(1000)*100})
df.index.name = 'index'
print(df.head())
# 创建数据

hist, edges = np.histogram(df['value'],bins=20)
print(hist[:5])
print(edges)
# 将数据解析成直方图统计格式
# 高阶函数np.histogram(a, bins=10, range=None, weights=None, density=None) 
# a：数据
# bins：箱数
# range：最大最小值的范围，如果不设定则为(a.min(), a.max())
# weights：权重
# density：为True则返回“频率”，为False则返回“计数”
# 返回值1 - hist：每个箱子的统计值（top）
# 返回值2 - edges：每个箱子的位置坐标，这里n个bins将会有n+1个edges

p = figure(title="HIST", tools="save",background_fill_color="#E8DDCB")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],   # 分别代表每个柱子的四边值
        fill_color="#036564", line_color="#033649")
# figure.quad绘制直方图

show(p)
# Out:
#             value
# index
# 0      170.869071
# 1     -209.130773
# 2       56.566721
# 3       80.262554
# 4       85.024765
# [ 1  0  3  7 18]
# [-361.04905309 -325.52466885 -290.00028461 -254.47590037 -218.95151614
#  -183.4271319  -147.90274766 -112.37836343  -76.85397919  -41.32959495
#    -5.80521072   29.71917352   65.24355776  100.767942    136.29232623
#   171.81671047  207.34109471  242.86547894  278.38986318  313.91424742
#   349.43863166]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8155275e-fb67-432e-821c-c79fd98945b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("8155275e-fb67-432e-821c-c79fd98945b6");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8155275e-fb67-432e-821c-c79fd98945b6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8155275e-fb67-432e-821c-c79fd98945b6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4a7432d8-01b3-4f4e-85bf-d3882ba6150a":{"roots":{"references":[{"attributes":{},"id":"6a99eac8-4537-44ff-b10f-fb564f14f2a3","type":"BasicTicker"},{"attributes":{},"id":"e6b5145e-8147-447e-9acd-b4b9d7a2206e","type":"BasicTickFormatter"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"29c60805-eb62-4106-8ca8-107cd2b9b7aa","type":"Quad"},{"attributes":{"callback":null},"id":"c47da042-24bd-4c4b-acf6-92b421730b0e","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"e49ffb73-66c7-4ba8-835b-78269d4ddda2","subtype":"Figure","type":"Plot"},"ticker":{"id":"168796b3-4b97-4b48-b0d3-cd606abfec81","type":"BasicTicker"}},"id":"9440ac89-6fff-4e74-a305-08c5264c5571","type":"Grid"},{"attributes":{"plot":null,"text":"HIST"},"id":"6f0dae32-d862-4931-a6da-e48881d278f0","type":"Title"},{"attributes":{"data_source":{"id":"9ca46a41-4d7d-4191-9c00-a8ac9172403a","type":"ColumnDataSource"},"glyph":{"id":"86bdd5e6-609f-4828-9256-c26a10716753","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"29c60805-eb62-4106-8ca8-107cd2b9b7aa","type":"Quad"},"selection_glyph":null,"view":{"id":"c7090c2b-a63c-4014-a26d-a7db50404b91","type":"CDSView"}},"id":"cbf6bd53-0fe6-46c1-b90e-6717d52f0806","type":"GlyphRenderer"},{"attributes":{"source":{"id":"9ca46a41-4d7d-4191-9c00-a8ac9172403a","type":"ColumnDataSource"}},"id":"c7090c2b-a63c-4014-a26d-a7db50404b91","type":"CDSView"},{"attributes":{},"id":"9cf0154b-bf1a-46d7-87ab-32b591a3e2b9","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":