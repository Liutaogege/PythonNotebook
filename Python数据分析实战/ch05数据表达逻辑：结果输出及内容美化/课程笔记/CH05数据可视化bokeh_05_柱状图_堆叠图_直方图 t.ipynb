# %% [markdown]
# '''
# 【课程5.6】  柱状图/堆叠图/直方图
#
# ① 单系列柱状图
# ② 多系列柱状图
# ③ 堆叠图
# ④ 直方图
#
# '''

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

from bokeh.io import output_notebook
output_notebook()

from bokeh.plotting import figure,show
from bokeh.models import ColumnDataSource
# 导入图表绘制、图标展示模块
# 导入ColumnDataSource模块
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6d489d61-0624-4f2d-a490-9c1b9e1d2c6a">Loading BokehJS ...</span>
#     </div>

# %%
#1，单系列柱状图
# vbar

p = figure(plot_width = 600,plot_height = 400)
p.vbar(x=[1, 2, 3], width=0.5, bottom=0,top=[1.2, 2.5, 3.7],  # x：横轴坐标，width：宽度，bottom：底高度，top：顶高度,bottom=[0.1,0,4,0.5]
       #color = ['red','blue','green'], alpha = 0.8   # 整体颜色设置，也可单独设置 → color="firebrick"
       line_width = 1,line_alpha = 0.8,line_color = 'black', line_dash = [5,2],    # 单独设置线参数
       fill_color = 'red',fill_alpha = 0.6    # 单独设置填充颜色参数
      )
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="914be4be-2cc9-4044-b194-7a5feebf9736"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("914be4be-2cc9-4044-b194-7a5feebf9736");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("914be4be-2cc9-4044-b194-7a5feebf9736");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '914be4be-2cc9-4044-b194-7a5feebf9736' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f0a71057-fb09-448e-b96d-6f738439cd9d":{"roots":{"references":[{"attributes":{"below":[{"id":"2a2a2cc2-7e3b-46e4-bb89-586e7bae82b9","type":"LinearAxis"}],"left":[{"id":"cb01c60d-5ef6-4f6b-aef6-1f9cd1df6758","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"2a2a2cc2-7e3b-46e4-bb89-586e7bae82b9","type":"LinearAxis"},{"id":"f36fef5e-880e-47f8-9d38-4bca56a48d69","type":"Grid"},{"id":"cb01c60d-5ef6-4f6b-aef6-1f9cd1df6758","type":"LinearAxis"},{"id":"f550bf00-2657-407c-a97c-7e74964b68b2","type":"Grid"},{"id":"51fedb47-28dd-4a34-a015-b1684c0c3266","type":"BoxAnnotation"},{"id":"083f5552-cce4-43a3-831c-8e98c52e5d0d","type":"GlyphRenderer"}],"title":{"id":"5dc5863a-2a75-4168-aa5e-1fc441b804b1","type":"Title"},"toolbar":{"id":"24577ecd-19aa-49d5-933b-ab7578eee185","type":"Toolbar"},"x_range":{"id":"8622221c-dda2-47ce-a9c8-6d273fa6c086","type":"DataRange1d"},"x_scale":{"id":"b5dd8230-806e-42f3-b692-e2be82883f20","type":"LinearScale"},"y_range":{"id":"1dea26c5-9b8f-4a72-9233-c73dabd9ac58","type":"DataRange1d"},"y_scale":{"id":"cac72180-a2f7-46b7-8d3a-83c6093b14fb","type":"LinearScale"}},"id":"9915eba1-5e6c-43c3-8dda-589b01881996","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"b5dd8230-806e-42f3-b692-e2be82883f20","type":"LinearScale"},{"attributes":{},"id":"de255e53-333a-48ca-bdbe-19317d631f12","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["top","x"],"data":{"top":[1.2,2.5,3.7],"x":[1,2,3]}},"id":"916f5fbb-cabe-48dc-be42-3e28a79b19b4","type":"ColumnDataSource"},{"attributes":{},"id":"a4f91c04-ff47-4357-8a21-af8fbcfebec6","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":
type":"HBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a059e027-5911-46c5-b63b-49e915c2f8c6","type":"HBar"},"selection_glyph":null,"view":{"id":"112d1f8a-8032-476c-96ab-615e708d35fc","type":"CDSView"}},"id":"41a3599a-a245-49e6-97a9-a7aed ...

# %%
# 1、单系列柱状图 - 分类设置标签
# ColumnDataSource
#若想使用文字标签，只能用columndatasource这种方法
from bokeh.palettes import Spectral6
from bokeh.transform import factor_cmap

fruits = ['apples','pears','grapes','banana','pinenapple','nuts']
counts = [2,4,5,7,3,1]
source = ColumnDataSource(data= dict(fruits=fruits,counts = counts))
colors = ['pink','purple','orange','olive','skyblue','gold']
#创建一个包含标签的data，对象类型为colunmndatasource

p = figure(x_range=fruits,y_range=(0,8),plot_height=350,title='水果数量',tools='')

p.vbar(x='fruits',top='counts',source=source,
      width=0.9,alpha=0.8,
      color=factor_cmap('fruits',palette=Spectral6,factors=fruits),
      legend='水果')
# 绘制柱状图，横轴直接显示标签
# factor_cmap(field_name, palette, factors, start=0, end=None, nan_color='gray')：颜色转换模块，生成一个颜色转换对象
# field_name：分类名称
# palette：调色盘
# factors：用于在调色盘中分颜色的参数
# 参考文档：http://bokeh.pydata.org/en/latest/docs/reference/transform.html


p.xgrid.grid_line_color = None
p.legend.orientation = 'horizontal'
p.legend.location = 'top_right'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6de97bf6-6065-4a83-97a8-7608a1b4309f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6de97bf6-6065-4a83-97a8-7608a1b4309f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6de97bf6-6065-4a83-97a8-7608a1b4309f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6de97bf6-6065-4a83-97a8-7608a1b4309f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2fa4ec5e-64bc-4cf4-bc44-2bd10f4e039e":{"roots":{"references":[{"attributes":{"label":{"value":"\u6c34\u679c"},"renderers":[{"id":"d89802c0-74ee-47c7-867a-4dd3782a5a8a","type":"GlyphRenderer"}]},"id":"eabd0283-17c3-4648-a650-b9200a795feb","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto"},"id":"a07274e9-f7d8-46ce-a37a-877a9a879588","type":"Toolbar"},{"attributes":{},"id":"944ef751-cb14-44cf-bf31-dea91732c757","type":"CategoricalTickFormatter"},{"attributes":{"below":[{"id":"8489fcfb-d339-4fb3-84e2-da9b99f03dc6","type":"CategoricalAxis"}],"left":[{"id":"326dcd8c-def1-4160-97d7-f3590f5b9c2a","type":"LinearAxis"}],"plot_height":350,"renderers":[{"id":"8489fcfb-d339-4fb3-84e2-da9b99f03dc6","type":"CategoricalAxis"},{"id":"8e5b6007-4864-4970-9c14-4ef39094b1da","type":"Grid"},{"id":"326dcd8c-def1-4160-97d7-f3590f5b9c2a","type":"LinearAxis"},{"id":"abaec399-db88-4bea-be15-a63c94d559c4","type":"Grid"},{"id":"e7518a1d-9fbc-449e-9f9d-765c945d7a5e","type":"Legend"},{"id":"d89802c0-74ee-47c7-867a-4dd3782a5a8a","type":"GlyphRenderer"}],"title":{"id":"5d4f27d4-1697-45b8-82e6-b4bbb322d8f3","type":"Title"},"toolbar":{"id":"a07274e9-f7d8-46ce-a37a-877a9a879588","type":"Toolbar"},"x_range":{"id":"c4caa818-4a51-4f2f-9a8f-b09ece403178","type":"FactorRange"},"x_scale":{"id":"a492a2a8-365e-465e-84b0-c2d8e68ff28b","type":"CategoricalScale"},"y_range":{"id":"5dd75690-d63a-4b10-8983-faf2ff34d20b","type":"Range1d"},"y_scale":{"id":"92c25a3c-c55e-4707-90c9-804cc8a8bfde","type":"LinearScale"}},"id":"ba600b05-e4a3-4ef6-81ea-438cd1cf8e20","subtype":"Figure","type":"Plot"},{"attributes":{"source":{"id":"8f08c658-2dd2-4b16-92a3-eb71dfedc6f9","type":"ColumnDataSource"}},"id":"393e3ace-0ab1-45f6-9007-20cc9c051674","type":"CDSView"},{"attributes":{},"id":"0d795553-6dae-4ea4-b74d-5e5d08effa87","type":"CategoricalTicker"},{"attributes":{"dimension":1,"plot":{"id":"ba600b05-e4a3-4ef6-81ea-438cd1cf8e20","subtype":"Figure","type":"Plot"},"ticker":{"id":"1ab50136-8cfe-46a1-a97d-551690c1f5ed","type":"BasicTicker"}},"id":"abaec399-db88-4bea-be15-a63c94d559c4","type":"Grid"},{"attributes":{"formatter":{"id":"944ef751-cb14-44cf-bf31-dea91732c757","type":"CategoricalTickFormatter"},"plot":{"id":"ba600b05-e4a3-4ef6-81ea-438cd1cf8e20","subtype":"Figure","type":"Plot"},"ticker":{"id":"0d795553-6dae-4ea4-b74d-5e5d08effa87","type":"CategoricalTicker"}},"id":"8489fcfb-d339-4fb3-84e2-da9b99f03dc6","type":"CategoricalAxis"},{"attributes":{"items":[{"id":"eabd0283-17c3-4648-a650-b9200a795feb","type":"LegendItem"}],"orientation":"horizontal","plot":{"id":"ba600b05-e4a3-4ef6-81ea-438cd1cf8e20","subtype":"Figure","type":"Plot"}},"id":"e7518a1d-9fbc-449e-9f9d-765c945d7a5e","type":"Legend"},{"attributes":{},"id":"a492a2a8-365e-465e-84b0-c2d8e68ff28b","type":"CategoricalScale"},{"attributes":{"plot":null,"text":"\u6c34\u679c\u6570\u91cf"},"id":"5d4f27d4-1697-45b8-82e6-b4bbb322d8f3","type":"Title"},{"attributes":{},"id":"92c25a3c-c55e-4707-90c9-804cc8a8bfde","type":"LinearScale"},{"attributes":{"factors":["apples","pears","grapes","banana","pinenapple","nuts"],"palette":["#3288bd","#99d594","#e6f598","#fee08b","#fc8d59","#d53e4f"]},"id":"13d8afdd-9fc9-4c29-8209-a23bec79eab9","type":"CategoricalColorMapper"},{"attributes":{"callback":null,"column_names":["counts","fruits"],"data":{"counts":[2,4,5,7,3,1],"fruits":["apples","pears","grapes","banana","pinenapple","nuts"]}},"id":"8f08c658-2dd2-4b16-92a3-eb71dfedc6f9","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["apples","pears","grapes","banana","pinenapple","nuts"]},"id":"c4caa818-4a51-4f2f-9a8f-b09ece403178","type":"FactorRange"},{"attributes":{"callback":null,"end":8},"id":"5dd75690-d63a-4b10-8983-faf2ff34d20b","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"field":"fruits","transform":{"id":"13d8afdd-9fc9-4c29-8209-a23bec79eab9","type":"CategoricalColorMapper"}},"line_alpha":{"value":0.8 ...

# %%
#dataframe构建柱状图可使用此方法
df = pd.DataFrame({'counts':[2,4,5,7,3,1],'colors':['pink','purple','orange','olive','skyblue','gold']}
                  )
p = figure(plot_width = 600,plot_height = 400)
p.vbar(x = df.index,width=0.5,bottom = 0,top =df['counts'],
      color = df['colors'])
show(p)
print(df)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"d6e9a1bd-9c66-4c30-aafc-206df6d46428","type":"LinearAxis"},{"id":"560e5917-5777-44f6-8d30-30291f83c9b2","type":"Grid"},{"id":"2b716419-06fc-4d01-89f8-d42d2240f837","type":"LinearAxis"},{"id":"d8120db7-23e1-4bf7-8201-29d1e9c66f8f","type":"Grid"},{"id":"b2808df4-b3b3-405c-a1a4-c98d79e2cc9a","type":"BoxAnnotation"},{"id":"c163199c-77ba-432f-aa5a-d8c2817792aa","type":"GlyphRenderer"}],"title":{"id" ...
#     colors  counts
# 0     pink       2
# 1   purple       4
# 2   orange       5
# 3    olive       7
# 4  skyblue       3
# 5     gold       1

# %%
# 2、多系列柱状图
# vbar
#ColumnDataSource经常是用于列表的，但也可以用于dataframe
from bokeh.transform import dodge
from bokeh.core.properties import value

df = pd.DataFrame({'2015':[2,3,4,5,10,8],'2016':[2,4,5,6,8,9],'2017':[9,3,2,7,5,3]},
                 index = ['appels','pears','bananas','nuts','pines','pineappels'])

fruits = df.index.tolist()
years = df.columns.tolist()
data = {'index':fruits}

for year in years:
    data[year] = df[year].tolist()
print(data)
# data数据格式为dict

source = ColumnDataSource(data = data)
#将数据转换为ColumnDataSource对象

p = figure(x_range = fruits,y_range=(0,13),plot_height = 400,title = '年水果量')
p.vbar(x=dodge('index',-0.25,range=p.x_range),top = '2015',width=0.2,source=source,color = 'red',legend=value('2015'))
p.vbar(x=dodge('index',0,range=p.x_range),top = '2016',width=0.2,source=source,color = 'yellow',legend=value('2016'))
p.vbar(x=dodge('index',0.25,range=p.x_range),top = '2017',width=0.2,source=source,color = 'blue',legend=value('2017'))
# 绘制多系列柱状图
# dodge(field_name, value, range=None) → 转换成一个可分组的对象，value为元素的位置（配合width设置）,相当于设置柱之间的空白间距
# value(val, transform=None) → 按照年份分为dict


p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"
# 其他参数设置

show(p)
# Out:
# {'2016': [2, 4, 5, 6, 8, 9], '2017': [9, 3, 2, 7, 5, 3], '2015': [2, 3, 4, 5, 10, 8], 'index': ['appels', 'pears', 'bananas', 'nuts', 'pines', 'pineappels']}
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="210c9b01-8e94-487c-bace-fcb51783f1af"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("210c9b01-8e94-487c-bace-fcb51783f1af");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("210c9b01-8e94-487c-bace-fcb51783f1af");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '210c9b01-8e94-487c-bace-fcb51783f1af' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0477debe-ebf0-48f6-914f-9ab52ae9d06e":{"roots":{"references":[{"attributes":{"data_source":{"id":"fb421729-aa44-4c51-987a-28ab650aa99e","type":"ColumnDataSource"},"glyph":{"id":"f5ea3c3e-95c7-44c4-bdae-c61f006c55c4","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8675d787-adee-4e26-8e60-96f200c69897","type":"VBar"},"selection_glyph":null,"view":{"id":"557bf0e6-afbf-4d20-b9fd-c2362df6f0c6","type":"CDSView"}},"id":"58c72d59-a2ba-42b5-8f3f-53a6a36bb093","type":"GlyphRenderer"},{"attributes":{},"id":"89aa3b40-2b91-4e39-ab66-35a37274a432","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":
from bokeh.core.properties import value

fruits = ['appels','pears','nuts','bananas','grapes','oranges']
years = ['2015','2016','2017']
colors = ['red','yellow','blue']
data = {'fruits':fruits,
       '2015':[2,1,4,5,6,6],
       '2016':[7,3,5,6,4,2],
       '2017':[2,3,5,8,1,2]}
source = ColumnDataSource(data = data)
p = figure(x_range=fruits,title = '年水果量')

renders = p.vbar_stack(years,# 设置堆叠值，这里source中包含了不同年份的值，years变量用于识别不同堆叠层
                      x = 'fruits',#设置坐标
                      source = source,
                      width = 0.9,color = colors,
                      legend = [value(x) for x in years],name=years)
# 绘制堆叠图
# 注意第一个参数需要放years
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"
# 设置其他参数

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51945adf-f9d2-480c-8e32-ecf991632d03"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("51945adf-f9d2-480c-8e32-ecf991632d03");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51945adf-f9d2-480c-8e32-ecf991632d03");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51945adf-f9d2-480c-8e32-ecf991632d03' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4e376464-0d70-4d6f-94f5-c3d0ada48ed0":{"roots":{"references":[{"attributes":{},"id":"ecabf421-ef1e-4540-8165-d2e645ffaa2e","type":"CategoricalScale"},{"attributes":{"bottom":{"expr":{"id":"95ba6a02-6f32-44bd-a025-aa00407ea9de","type":"Stack"}},"fill_color":{"value":"red"},"line_color":{"value":"red"},"top":{"expr":{"id":"a9784ea9-2c66-43df-b042-99e44ff14302","type":"Stack"}},"width":{"value":0.9},"x":{"field":"fruits"}},"id":"6dedc2fd-d567-4cf9-a076-3ea85740fb8f","type":"VBar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"60b7578a-ce62-489d-9c4c-dc78a12e4cd4","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cd63c90e-4cb2-418b-bb75-0d7692913432","type":"PanTool"},{"id":"6f35cee8-7bd4-4c9f-96c2-f4fced244972","type":"WheelZoomTool"},{"id":"aad0851a-e66e-4970-80c6-7e5d083b32e3","type":"BoxZoomTool"},{"id":"032931f6-0ced-4ca3-8217-4f3e2867c657","type":"SaveTool"},{"id":"d912177c-002d-41b7-8611-bddc665165db","type":"ResetTool"},{"id":"5acf19b8-8042-4473-9065-a6190f45acda","type":"HelpTool"}]},"id":"2c45b33d-c455-4c1e-9eb9-96f12a6bb5fb","type":"Toolbar"},{"attributes":{"fields":["2015","2016","2017"]},"id":"d3aebe4c-1cb4-4965-8fae-9a4a9742f97d","type":"Stack"},{"attributes":{},"id":"d912177c-002d-41b7-8611-bddc665165db","type":"ResetTool"},{"attributes":{"fields":["2015","2016"]},"id":"01623ff6-9667-44f5-bc13-2db21539362f","type":"Stack"},{"attributes":{"formatter":{"id":"98aebea5-36e5-4fed-88db-221c6bb8d77f","type":"CategoricalTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"9cb9e716-98b0-46c7-9bc1-caded98bd4cd","subtype":"Figure","type":"Plot"},"ticker":{"id":"624570e7-62f6-4d8b-bcec-e0835491c962","type":"CategoricalTicker"}},"id":"e56711ef-4aab-468c-a51f-de17d47fec92","type":"CategoricalAxis"},{"attributes":{"source":{"id":"ee7c8f4e-6f5d-42b1-806b-efc3c5e38ee8","type":"ColumnDataSource"}},"id":"5e46baa0-2089-4289-b932-c35f091d20fb","type":"CDSView"},{"attributes":{},"id":"98aebea5-36e5-4fed-88db-221c6bb8d77f","type":"CategoricalTickFormatter"},{"attributes":{"overlay":{"id":"60b7578a-ce62-489d-9c4c-dc78a12e4cd4","type":"BoxAnnotation"}},"id":"aad0851a-e66e-4970-80c6-7e5d083b32e3","type":"BoxZoomTool"},{"attributes":{"items":[{"id":"fbd8147c-b5db-40ad-b604-e3424886d283","type":"LegendItem"},{"id":"8ad18a1d-06d6-407d-8b16-98959a7e4689","type":"LegendItem"},{"id":"8366db74-0236-4616-bbeb-df09bb4c708d","type":"LegendItem"}],"location":"top_left","orientation":"horizontal","plot":{"id":"9cb9e716-98b0-46c7-9bc1-caded98bd4cd","subtype":"Figure","type":"Plot"}},"id":"9c8f9fd2-df38-4de3-a047-d16cc8dc7c0f","type":"Legend"},{"attributes":{"callback":null,"factors":["appels","pears","nuts","bananas","grapes","oranges"]},"id":"acd0d8ed-361f-4d67-9e01-98a4aba22826","type":"FactorRange"},{"attributes":{"bottom":{"expr":{"id":"e8ffbf76-5a4c-4fe1-b582-a09f71308648","type":"Stack"}},"fill_color":{"value":"yellow"},"line_color":{"value":"yellow"},"top":{"expr":{"id":"e4f6fd79-bfe6-4044-a294-9e7f5c054af4","type":"Stack"}},"width":{"value":0.9},"x":{"field":"fruits"}},"id":"de84ebcd-ed80-46f9-aec5-c6e046b249d9","type":"VBar"},{"attributes":{"fields":[]},"id":"95ba6a02-6f32-44bd-a025-aa00407ea9de","type":"Stack"},{"attributes":{},"id":"676fb769-cbb3-4f95-bf5c-44ef33b3d975","type":"BasicTickFormatter"},{"attributes":{"fields":["2015","2016"]},"id":"e4f6fd79-bfe6-4044-a294-9e7f5c054af4","type":"Stack"},{"attributes":{"fields":["2015"]},"id":"e8ffbf76-5a4c-4fe1-b582-a09f71308648","type":"Stack"},{"attributes":{},"id":"2d9c9950-3a02-41c1-ac3e-ef851ff8a85c","type":"BasicTicker"},{"attributes":{},"id":"624570e7-62f6-4d8b-bcec-e0835491c962","t ...

# %%
# 堆叠图

from bokeh.palettes import GnBu3,OrRd3

fruits = ['appels','pears','nuts','bananas','grapes','oranges']
years = ['2015','2016','2017']
exports ={'fruits':fruits,
       '2015':[2,1,4,5,6,6],
       '2016':[7,3,5,6,4,2],
       '2017':[2,3,5,8,1,2]}
imports = {'fruits':fruits,
       '2015':[-1,-1,-7,-5,-5,6],
       '2016':[-5,-3,-2,-6,-2,-2],
       '2017':[-1,-4,-5,-4,-1,-2]}

p = figure(y_range=fruits, plot_height=350, x_range=(-16, 16), title="Fruit import/export, by year")

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3, source=ColumnDataSource(exports),
             legend=["%s exports" % x for x in years])      # 绘制出口数据堆叠图

p.hbar_stack(years, y='fruits', height=0.9, color=OrRd3, source=ColumnDataSource(imports),
             legend=["%s imports" % x for x in years])      # 绘制进口数据堆叠图，这里值为负值

p.y_range.range_padding = 0.2     # 调整边界间隔
p.ygrid.grid_line_color = None   
p.legend.location = "top_left"
p.axis.minor_tick_line_color = None
p.outline_line_color = None
# 设置其他参数


show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="571af335-7e44-4483-830c-b7d2561682c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("571af335-7e44-4483-830c-b7d2561682c8");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("571af335-7e44-4483-830c-b7d2561682c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '571af335-7e44-4483-830c-b7d2561682c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"537adca5-40e1-41ee-a6e6-1c34ddc99081":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.9},"left":{"expr":{"id":"d76e8442-ad53-48bb-82aa-f09c15a71c10","type":"Stack"}},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"expr":{"id":
":"f8058510-5502-408f-b26d-dfb63fdbf102","type":"LegendItem"},{"attributes":{"fill_color":{"value":"#e34a33"},"height":{"value":0.9},"left":{"expr":{"id":"f5fb2306-f6a9-4d47-ae34-f6aa0b079f3b","type":"Stack"}},"line_color":{"value":"#e34a33"},"right":{"expr":{"id":"936e5ce8-4c7d-4954-b27a-d9814dd63399","type":"Stack"}},"y":{"field":"fruits"}},"id":"bbc07d8c-4e8a-4998-85b6-39f5629c8402","type":"HBar"},{"attributes":{},"id":"884dfd8d-d3b3-492a-80 ...

# %%
# 4、直方图
# np.histogram + figure.quad()
# 不需要构建ColumnDataSource对象

df = pd.DataFrame({'value':np.random.randn(1000)*100})
df.index.name = 'index'

hist,edges = np.histogram(df['value'],bins=20)
print(hist[:5])
print(edges)

# 将数据解析成直方图统计格式
# 高阶函数np.histogram(a, bins=10, range=None, weights=None, density=None) 
# a：数据
# bins：箱数
# range：最大最小值的范围，如果不设定则为(a.min(), a.max())
# weights：权重
# density：为True则返回“频率”，为False则返回“计数”
# 返回值1 - hist：每个箱子的统计值（top）
# 返回值2 - edges：每个箱子的位置坐标，这里n个bins将会有n+1个edges

p = figure()
p = figure(title="HIST", tools="save",background_fill_color="#E8DDCB")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],   # 分别代表每个柱子的四边值
        fill_color="#036564", line_color="#033649")
# figure.quad绘制直方图

show(p)
# Out:
# [ 1  0  2  3 15]
# [-363.05676747 -329.82780072 -296.59883397 -263.36986722 -230.14090047
#  -196.91193372 -163.68296696 -130.45400021  -97.22503346  -63.99606671
#   -30.76709996    2.46186679   35.69083355   68.9198003   102.14876705
#   135.3777338   168.60670055  201.83566731  235.06463406  268.29360081
#   301.52256756]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7a60631c-fc6c-4606-b944-e4b0a2880db9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("7a60631c-fc6c-4606-b944-e4b0a2880db9");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7a60631c-fc6c-4606-b944-e4b0a2880db9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7a60631c-fc6c-4606-b944-e4b0a2880db9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1dc6a8e0-4ddf-47de-a5bb-5cb7a129b747":{"roots":{"references":[{"attributes":{"plot":null,"text":"HIST"},"id":"722daab9-65fd-44b7-b53e-56b4c206ac9f","type":"Title"},{"attributes":{"source":{"id":"7eedad0f-4129-40da-961a-9140f5e03570","type":"ColumnDataSource"}},"id":"f845c6ab-0986-4bdb-a25b-42418281a09a","type":"CDSView"},{"attributes":{"formatter":{"id":"1e6ae3c7-ee3f-4149-bd8e-e3f38b5d5358","type":"BasicTickFormatter"},"plot":{"id":"5440efc2-7b46-4ef6-924f-b448a38eef27","subtype":"Figure","type":"Plot"},"ticker":{"id":"5b3663b7-d9e9-4209-842a-db03c90bff8f","type":"BasicTicker"}},"id":"bd0d1994-6fe5-40dc-a9f4-1ae57c649623","type":"LinearAxis"},{"attributes":{},"id":"5b3663b7-d9e9-4209-842a-db03c90bff8f","type":"BasicTicker"},{"attributes":{},"id":"ba82743f-2d23-44cc-b98f-1fa806acac27","type":"LinearScale"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":